# %% [markdown]
# # VKontakte crawling for NGOs
#
# For each NGO that is present in VK social media we want to find out:
#
# - number of subscribers
# - how often the post. Posts per months for starters
# - number of likes on each post (then get a mean)
# - number of comments on each post (then get a mean)
#
# > 1 день -- собрать сами ссылки организаций на вк, подготовить датасет. 3 дня написать базу данных куда складывать всю информацию под вк, в json будет неудобно, потому что по сути у каждой организации отдельная свзяанная таблица по соцсетям. Потом эту бд можно использовать и для следующих соцсетей. Сбор данных 2-3 дня. Всего 6-7 дней.
#
# ## Load the dataset

# %%
import pandas as pd
import numpy as np
import re

# %%
# !pip install vk_api
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: vk_api in c:\users\admin\appdata\roaming\python\python38\site-packages (11.9.9)
# Requirement already satisfied: requests in c:\program files\python38\lib\site-packages (from vk_api) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\program files\python38\lib\site-packages (from requests->vk_api) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\program files\python38\lib\site-packages (from requests->vk_api) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\program files\python38\lib\site-packages (from requests->vk_api) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\program files\python38\lib\site-packages (from requests->vk_api) (2020.12.5)
# WARNING: You are using pip version 21.1.2; however, version 22.1.2 is available.
# You should consider upgrading via the 'c:\program files\python38\python.exe -m pip install --upgrade pip' command.

# %%
# !ls
# Out:
# 2021 - Lab - Google PageSpeed Insights Lighthouse Tests.ipynb
# 2021 - Lab - whois check.ipynb
# 2021 - OpenNGO dumps filters.ipynb
# 2021_Lab_Tests_for_websites_communicative_capacity.ipynb
# 2022_ngos_hostings.ipynb
# 2022_ngos_vk.ipynb
# 2022_web_archive_ngos.ipynb
# util.py

# %%
ngo_vks = pd.read_csv("../../vk_links.csv", encoding="utf-8")
ngo_vks.head()
# Out:
#                                    vk
# 0  \nhttps://vk.com/bsdipol_manager\n
# 1            //vk.com/avtoshkola_adpo
# 2                //vk.com/bfdetizemli
# 3             //vk.com/bryanskeparhia
# 4                     //vk.com/budros

# %%
len(ngo_vks)
# Out:
# 4522

# %%
all_socials = pd.read_csv("../data/2021_dec_social_networks_check.csv", encoding="utf-8")
all_socials.head()
# Out:
#                               url   fb                                   vk  \
# 0  http://burningheart-charity.ru  NaN                                  NaN
# 1             http://nkosocium.ru  NaN                                  NaN
# 2               http://rck-vlg.ru  NaN                                  NaN
# 3              http://rtsk-vlg.ru  NaN                                  NaN
# 4  http://intellect-foundation.ru  NaN  https://vk.com/intellect.foundation
#
#                                            ig   ok youtube tiktok
# 0                                         NaN  NaN     NaN    NaN
# 1                                         NaN  NaN     NaN    NaN
# 2                                         NaN  NaN     NaN    NaN
# 3                                         NaN  NaN     NaN    NaN
# 4  https://instagram.com/intellect.foundation  NaN     NaN    NaN

# %%
all_socials[~all_socials["vk"].isnull()]
# Out:
#                                   url  \
# 4      http://intellect-foundation.ru
# 12      http://рбоонадежда47регион.рф
# 14            http://securitymedia.ru
# 18        http://ecology-tatarstan.ru
# 22                  http://dvbfond.ru
# ...                               ...
# 12274                 http://arpko.ru
# 12279           http://icrt-russia.ru
# 12280    http://moscowfilmfestival.ru
# 12287                 http://kcmol.ru
# 12292       http://автошколаколесо.рф
#
#                                                    fb  \
# 4                                                 NaN
# 12                                                NaN
# 14     https://www.facebook.com/industriabezopasnosti
# 18                                                NaN
# 22                                                NaN
# ...                                               ...
# 12274                  http://www.facebook.com/nprpko
# 12279   https://www.facebook.com/sot.icrt.russia.cis/
# 12280                                             NaN
# 12287                                             NaN
# 12292                                             NaN
#
#                                                       vk  \
# 4                    https://vk.com/intellect.foundation
# 12     https://vk.com/pomoschsemie.luga?w=app5619682_...
# 14                          https://vk.com/securitymedia
# 18                        https://vk.com/public173749519
# 22                       https://vk.com/fonddobrovoblago
# ...                                                  ...
# 12274                                http://vk.com/arpko
# 12279                          https://vk.com/icrtrussia
# 12280                                https://vk.com/mmkf
# 12287                            https://vk.com/kcmkursk
# 12292                            https://vk.com/kolesonn
#
#                                                     ig   ok  \
# 4           https://instagram.com/intellect.foundation  NaN
# 12                                                 NaN  NaN
# 14                                                 NaN  NaN
# 18                                                 NaN  NaN
# 22     https://www.instagram.com/kirillpetrovhelp_sma/  NaN
# ...                                                ...  ...
# 12274                                              NaN  NaN
# 12279            https://www.instagram.com/icrtrussia/  NaN
# 12280                                              NaN  NaN
# 12287     https://www.instagram.com/_evolution_dance_/  NaN
# 12292              https://www.instagram.com/koleso_nn  NaN
#
#                                                  youtube tiktok
# 4                                                    NaN    NaN
# 12                                                   NaN    NaN
# 14                                                   NaN    NaN
# 18                                                   NaN    NaN
# 22     https://www.youtube.com/channel/UCiwOoMTRTDMa2...    NaN
# ...                                                  ...    ...
# 12274                                                NaN    NaN
# 12279  https://www.youtube.com/channel/UCOvJ2-PBIKO5A...    NaN
# 12280                                                NaN    NaN
# 12287                                                NaN    NaN
# 12292                                                NaN    NaN
#
# [4569 rows x 7 columns]

# %% [markdown]
# This dataset from Gryadka `2021_dec_social_networks_check.csv` has more vk links (4569 > 4522).
#
# ## VK API minimal example
#
# Access token is valid only for 24 hours: https://dev.vk.com/api/getting-started

# %%
access_token = "vk1.a.z4MWINFBe0oM30zxrv8CPcLFDZcyExEgEM2bY9fJOUS2gtrYdjczK6JM2Zli5HAzLv0XRG_Od8Etw1PzvEYrFbgG4PPMGtgdSN02JSHWoh3cC_IIA1NP0QCYDbA8R8NR25VZWv5wfrXj1XW58iszIbm0QADCIr_m6jZI1qAwadOsSw38fhC4KCCC5H10k8Gf"

# proxy 144.76.241.45 port 7890 http
# access_token = "vk1.a.IeIpn6w6Ki9hM9HDW41gJSuNNrzEdgWZp6LzD0bz1w9OihY9DWzy2A_rpY1gW3YGRF0LEnIZlE-Z9JuKkhZrFmITmkNJdw1levUHe44udHbkUqE1zR3hER-scRvFs9A0GkHUO78fMAnTKRlPD85Z7I-5M9bcqtirmB3PClRcomgggcldRUwIq6k81IEOAqIP"

# expires_in=86400&user_id=26537712

# %%
import requests

response = requests.get("https://api.vk.com/method/friends.getOnline?v=5.131&access_token=" + access_token)
# proxies={"http": "http://144.76.241.45:7890", "https": "http://144.76.241.45:7890"})
response.text
# Out:
# '{"response":[7265079,7592964,14909720,18774990,22522985,26402925,38220308,38550321,43269671,47142125,52732921,55278550,66340837,75602894,84799526,86350202,91813902,102899215,118572031,122503981,167829096,177553912,190566081,191309594,224099941,244474708,265419885]}'

# %% [markdown]
# ## How to obtain groups data (Minimal example)
#
# 1. Number of members:

# %%
from random import choice



def send_request(request):
    # send request to VK api
    user_agent_list = [
                         'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/13.1.1 Safari/605.1.15',
                         'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:77.0) Gecko/20100101 Firefox/77.0',
                         'Mozilla/5.0 (Windows NT 5.1; rv:40.0) Gecko/20100101 Firefox/40.0',
                         'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
                         'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:77.0) Gecko/20100101 Firefox/77.0',
                         'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
                         'Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/28.0.1500.72 Safari/537.36',
                         'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10) AppleWebKit/600.1.25 (KHTML, like Gecko) Version/8.0 Safari/600.1.25',
                         'Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/38.0.2125.111 Safari/537.36',
                         'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_5) AppleWebKit/600.1.17 (KHTML, like Gecko) Version/7.1 Safari/537.85.10',
                         'Mozilla/5.0 (Windows NT 6.1; WOW64; Trident/7.0; rv:11.0) like Gecko',
                         'Mozilla/5.0 (Windows NT 6.3; WOW64; rv:33.0) Gecko/20100101 Firefox/33.0',
                        ]

    user_agent = choice(user_agent_list)
    user_agent_headers = {
        'User-Agent': user_agent
    }
    # proxies = ['http://78.47.16.54:80', 'http://203.75.190.21:80', 'http://77.72.3.163:80']
    # proxy = choice(proxies)
    response = requests.get(request + access_token,
                            headers=user_agent_headers,
                            timeout=3)
                            # proxies={"http": "http://144.76.241.45:7890", "https": "http://144.76.241.45:7890"})   #, proxies = {"http": proxy, "https": proxy})
    return response.text

# %%
vk_request = "https://api.vk.com/method/groups.getMembers?group_id=intellect.foundation&v=5.131&access_token="

send_request(vk_request)
# Out:
# '{"response":{"count":53,"items":[978510,1186608,4695292,5385373,6266011,6368304,13316957,23032683,31672175,44044409,59181088,66034160,106381670,135416887,176390692,208394706,223715795,229917761,235997690,240906543,242923279,263655933,266170494,287209588,290266258,310894347,321070784,367796163,381146828,401464040,425154997,445264090,445299987,490797121,512299272,552660702,584452216,588078019,616103852,618947324,621827122,625500385,629306409,639300133,645511319,645939370,647270929,650114051,654144713,655520219,655981830,657557589,675664434]}}'

# %% [markdown]
# 2. How often group posts. Posts per months for starters. `wall.get`

# %%
from pprint import pprint


vk_request = "https://api.vk.com/method/wall.get?domain=pomoschsemie.luga&v=5.131&access_token="

pprint(send_request(vk_request))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# d:\python371\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     594             if is_new_proxy_conn:
# --> 595                 self._prepare_proxy(conn)
#     596
#
# d:\python371\lib\site-packages\urllib3\connectionpool.py in _prepare_proxy(self, conn)
#     815
# --> 816         conn.connect()
#     817
#
# d:\python371\lib\site-packages\urllib3\connection.py in connect(self)
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#
# d:\python371\lib\site-packages\urllib3\util\ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#
# d:\python371\lib\ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     411             context=self,
# --> 412             session=session
#     413         )
#
# d:\python371\lib\ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     852                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 853                     self.do_handshake()
#     854             except (OSError, ValueError):
#
# d:\python371\lib\ssl.py in do_handshake(self, block)
#    1116                 self.settimeout(None)
# -> 1117             self._sslobj.do_handshake()
#    1118         finally:
#
# OSError: [Errno 0] Error
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# d:\python371\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# d:\python371\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     638             retries = retries.increment(method, url, error=e, _pool=self,
# --> 639                                         _stacktrace=sys.exc_info()[2])
#     640             retries.sleep()
#
# d:\python371\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     387         if new_retry.is_exhausted():
# --> 388             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     389
#
# MaxRetryError: HTTPSConnectionPool(host='api.vk.com', port=443): Max retries exceeded with url: /method/wall.get?domain=pomoschsemie.luga&v=5.131&access_token=vk1.a.IeIpn6w6Ki9hM9HDW41gJSuNNrzEdgWZp6LzD0bz1w9OihY9DWzy2A_rpY1gW3YGRF0LEnIZlE-Z9JuKkhZrFmITmkNJdw1levUHe44udHbkUqE1zR3hER-scRvFs9A0GkHUO78fMAnTKRlPD85Z7I-5M9bcqtirmB3PClRcomgggcldRUwIq6k81IEOAqIP (Caused by ProxyError('Cannot connect to proxy.', OSError(0, 'Error')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# <ipython-input-20-72c6ee5de130> in <module>
#       4 vk_request = "https://api.vk.com/method/wall.get?domain=pomoschsemie.luga&v=5.131&access_token="
#       5
# ----> 6 pprint(send_request(vk_request))
#
# <ipython-input-13-52c5db3011cb> in send_request(request)
#      29                             headers=user_agent_headers,
#      30                             timeout=3,
# ---> 31                             proxies={"http": "http://144.76.241.45:7890", "https": "http://144.76.241.45:7890"})   #, proxies = {"http": proxy, "https": proxy})
#      32     return response.text
#
# d:\python371\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# d:\python371\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# d:\python371\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# d:\python371\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# d:\python371\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     508
#     509             if isinstance(e.reason, _ProxyError):
# --> 510                 raise ProxyError(e, request=request)
#     511
#     512             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPSConnectionPool(host='api.vk.com', port=443): Max retries exceeded with url: /method/wall.get?domain=pomoschsemie.luga&v=5.131&access_token=vk1.a.IeIpn6w6Ki9hM9HDW41gJSuNNrzEdgWZp6LzD0bz1w9OihY9DWzy2A_rpY1gW3YGRF0LEnIZlE-Z9JuKkhZrFmITmkNJdw1levUHe44udHbkUqE1zR3hER-scRvFs9A0GkHUO78fMAnTKRlPD85Z7I-5M9bcqtirmB3PClRcomgggcldRUwIq6k81IEOAqIP (Caused by ProxyError('Cannot connect to proxy.', OSError(0, 'Error')))

# %%
res = send_request(vk_request)

# %%
import json
response = json.loads(res)

# %%
for item in response["response"]["items"]:
    if item["post_type"] != "post":
        pprint(item)
# Out:
# {'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#  'copy_history': [{'attachments': [{'photo': {'access_key': 'de4a1da3622d7f51a9',
#                                               'album_id': -7,
#                                               'date': 1656390169,
#                                               'has_tags': False,
#                                               'id': 457245273,
#                                               'owner_id': -1138759,
#                                               'sizes': [{'height': 75,
#                                                          'type': 's',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/-MCwzWKz5B281_CQ1AotlPqfnu6Y5ry_e_1ufGMytn6kOV9Ot6bHSjHtkVNLxYiYep6im6IEkb3NoaJHLNWY2JVH.jpg?size=53x75&quality=95&type=album',
#                                                          'width': 53},
#                                                         {'height': 130,
#                                                          'type': 'm',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/nYgCEHw3qmr9EXW90he8kSCfylfQXpKkJiJX8eM1TFqk_PBnvxAlh0nxDQIef8wgj9iYb5u62ZmVrXB0Z3SEDQCV.jpg?size=92x130&quality=95&type=album',
#                                                          'width': 92},
#                                                         {'height': 604,
#                                                          'type': 'x',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/M0ollzN2_S3MLARuWJRgjWi37RKEeHNIANMn0OKymW-x71H4tlg-JmClFO5cckKPlAyILVEURl2yZmKM7VYdGdda.jpg?size=428x604&quality=95&type=album',
#                                                          'width': 428},
#                                                         {'height': 807,
#                                                          'type': 'y',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/jFAos32w7BfUzRA_NSMMdrNxVUWBt28Xaxzs-I-p_1_2a6jPIiF3-V0GAXLx22IIGEr4WtEDbrvTW0IqrXZeQq-R.jpg?size=571x807&quality=95&type=album',
#                                                          'width': 571},
#                                                         {'height': 1080,
#                                                          'type': 'z',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/KiMbRhARsnPgSezEMw837aQeU3gcQjBudqQrcuO5lBfvHlwcI54ylOzrvtVbXHrbPkrloyHJ6sDQgpWDEmP3mYLB.jpg?size=764x1080&quality=95&type=album',
#                                                          'width': 764},
#                                                         {'height': 1920,
#                                                          'type': 'w',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/bhOLF8IPzpcz3WTBxvw6Xbo7Smc0B2rhjn7_54gDd8Sw8jBADr_-qPJ6meeDKpoiUHQFeuO7kj5nQ429PVdcqF0S.jpg?size=1359x1920&quality=95&type=album',
#                                                          'width': 1359},
#                                                         {'height': 184,
#                                                          'type': 'o',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/FDvcqKr_d2SfS06Y9XIEW74wZ9f6u-yhmzinzDPBV86lRSWcjVQ1RIrGIyMb0ub2NjUZHencTLw_yIKKE15Qmzxp.jpg?size=130x184&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 283,
#                                                          'type': 'p',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/1_rWA6DL4FVIbGavuFd-2QSJNu44XXDiOH9UyAVp9l54n2hcLIVv_B2yYhCuRzEm2vb2AHuGeKJL2hL2lToDy1fe.jpg?size=200x283&quality=95&type=album',
#                                                          'width': 200},
#                                                         {'height': 452,
#                                                          'type': 'q',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/wt2-TxoxaoRtHAtLFQCwkJ5ZWqLijaIYqQqt3oomk2A1xZKhnBh0c2iQcxGXH23hTNVoGfOsIXfUb99UFUW3Xy4p.jpg?size=320x452&quality=95&type=album',
#                                                          'width': 320},
#                                                         {'height': 721,
#                                                          'type': 'r',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-74/s/v1/if2/SZ2ybLo7xsEL5VVwGKatWvXcKZcC3DBI2YdXwEr3KYg9E3rP4NflpSoz9k7ahYE2KuOwF-SGa5otABB6LLYUX9es.jpg?size=510x721&quality=95&type=album',
#                                                          'width': 510}],
#                                               'text': '',
#                                               'user_id': 100},
#                                     'type': 'photo'},
#                                    {'photo': {'access_key': '639386cc5d032a495d',
#                                               'album_id': -7,
#                                               'date': 1656390169,
#                                               'has_tags': False,
#                                               'id': 457245274,
#                                               'owner_id': -1138759,
#                                               'sizes': [{'height': 75,
#                                                          'type': 's',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/b34JHIoNf0yb51FLu0LacrtI3PsLkFfGCepMCcseYCYdelMUCEU1o9ML7UTSLKKJ0RVkFZ-EeiZY0PK7tD06cN2c.jpg?size=53x75&quality=95&type=album',
#                                                          'width': 53},
#                                                         {'height': 130,
#                                                          'type': 'm',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/mZnB7RITOJULi8b5-Yf677VDoUaIbIXhaFmJTwZVcvPjFDulYGge1OomJUdTEKxHCHxQNOjbkNMjKvVEs_EtPz33.jpg?size=92x130&quality=95&type=album',
#                                                          'width': 92},
#                                                         {'height': 604,
#                                                          'type': 'x',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/HbTgZ3yUqSpV7ybbNKDwM_dsRWCXtpRDSdmxVVParGQarY_o4VRkJlklmzh33qeIxoncQmQlI1SFrWKI58uTCpVo.jpg?size=427x604&quality=95&type=album',
#                                                          'width': 427},
#                                                         {'height': 807,
#                                                          'type': 'y',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/RIyUhN1MwMrXMrITmByY1gvLVBFjDUV_qsI2MqMQgy9SFaMsUZEOmT1mHARzq5h0SSN8RynmQ7FkE1wSkfk_2j_2.jpg?size=570x807&quality=95&type=album',
#                                                          'width': 570},
#                                                         {'height': 1080,
#                                                          'type': 'z',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/S_FJkZWtHGICJ78RKUv0g6_S7wcmKEHSTTDqNj4pGbv4RzjJwZ0tViQibDo2sOLHrBrwoB1UfVp6azsX1DZ_Qodg.jpg?size=763x1080&quality=95&type=album',
#                                                          'width': 763},
#                                                         {'height': 1920,
#                                                          'type': 'w',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/bxCm_Buu3EZuofcOojnt8VvnZ3tzHhsXXCggRLuulQIKVTCQDE8ileCjGgvg5M92p3EyUv65EtjLTyHOdCAg7-_Y.jpg?size=1357x1920&quality=95&type=album',
#                                                          'width': 1357},
#                                                         {'height': 184,
#                                                          'type': 'o',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/j_hC7Z0mHNecrPEYyo-yRtOJ4V3W6NjOflkjDX_29FkWbInnV5wE7DPxE2I3d0fOTr3VY6yD16aAynsdv5Msqs2O.jpg?size=130x184&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 283,
#                                                          'type': 'p',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/ctcI7yzbP-tIrnyUo9lZjELcqhlD1S46fDWk3OCPGOGg1pFjDLTCQn4AdJDSQsfrcjf0JMSxxwzEJgcd02dHxNUR.jpg?size=200x283&quality=95&type=album',
#                                                          'width': 200},
#                                                         {'height': 453,
#                                                          'type': 'q',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/RwG5Jt7JQuLNXtI0KjL88IfofjJSZZVTPMz4cU9067pRnTXNUGkYxq6yF368J5Z0kzC0mOpvHlVWFhNTXPjvDEW-.jpg?size=320x453&quality=95&type=album',
#                                                          'width': 320},
#                                                         {'height': 722,
#                                                          'type': 'r',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-6/s/v1/if2/J2_3He5WhM0TMtWWqXxzYg8YURri26tGuf-IL5Fw_afViBPjY-PzGvagJl5dZQCBAttYFSGb5nc-4N0kHA6Buv04.jpg?size=510x722&quality=95&type=album',
#                                                          'width': 510}],
#                                               'text': '',
#                                               'user_id': 100},
#                                     'type': 'photo'},
#                                    {'photo': {'access_key': '72f1e34c79b4cdb34f',
#                                               'album_id': -7,
#                                               'date': 1656390169,
#                                               'has_tags': False,
#                                               'id': 457245275,
#                                               'owner_id': -1138759,
#                                               'sizes': [{'height': 75,
#                                                          'type': 's',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/-T5xGmPWKxK5_3Zn56J60ZT2MTKNrKn3LDPLSKixm-oXZQrl8ImM6VT1aHUDd_n9S6fu317x9SAOZOkmi3dtZHU5.jpg?size=53x75&quality=95&type=album',
#                                                          'width': 53},
#                                                         {'height': 130,
#                                                          'type': 'm',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/F-5WnZBBPAoumfa3KRjoibi1hSP8lXAB2vVauVsUJsLsH7dp9OQPcuv866zrtsmFPoOQUptyCH78TySWJnT0F_S2.jpg?size=92x130&quality=95&type=album',
#                                                          'width': 92},
#                                                         {'height': 604,
#                                                          'type': 'x',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/Q-IdKBPfLWJQcFrIqBBAewM9ognoGuc_RhXS04Avdd-NLfM0Eub_u2zs5KPA91coHKnKqxMysah2OoQIBLWL0dLI.jpg?size=427x604&quality=95&type=album',
#                                                          'width': 427},
#                                                         {'height': 807,
#                                                          'type': 'y',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/F4a2EVjkav_EcCctm06d1uh89YuEyvJwR0qg-63EBVwtMmuCd69olVovYzrBPijoxjNXiUgV-FO63Y-0c5ZacCVY.jpg?size=570x807&quality=95&type=album',
#                                                          'width': 570},
#                                                         {'height': 1080,
#                                                          'type': 'z',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/GV1TJx-9-hGiwFHWtMjNDkL92wIDkmjfRQQjbQN2N9ALccJDMLXSXnq2drMDFSrNXovfWvF8ts_cZPzdqtLpIDx-.jpg?size=763x1080&quality=95&type=album',
#                                                          'width': 763},
#                                                         {'height': 1920,
#                                                          'type': 'w',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/rDdO1UFLqLrf8669JyoIXedv8bQW8N5USDA0GT4OFxzmTtrOruyAGIt0ifIrrZVUADpVpldEYr4sJXEe3w77Qcu4.jpg?size=1357x1920&quality=95&type=album',
#                                                          'width': 1357},
#                                                         {'height': 184,
#                                                          'type': 'o',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/fjZnwd1Kzek1OLSpNjH-52LjbKICwIN4ShhejhMJGXHlBRzYiWrxHMGrno-F7QDP25vNry8C-R1rTZC7Sywf-SdM.jpg?size=130x184&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 283,
#                                                          'type': 'p',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/lz_kh6zC_A0PmfEXZcWG32ZFaPFPzSGqVRNJCfuUeQQ8Cq3cYVacnl9OZE9rzvKctnilIAiqijz8UulT9Uz2qwej.jpg?size=200x283&quality=95&type=album',
#                                                          'width': 200},
#                                                         {'height': 453,
#                                                          'type': 'q',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/-OfBXKbm_uKFG2MzCzXlNCTpbEbtoCf2rSmr-ZVdlXsThQxGWZ8OKh4L8Kyhqjh5hrKbYrmhDbtWa-r6WxqvMZ-E.jpg?size=320x453&quality=95&type=album',
#                                                          'width': 320},
#                                                         {'height': 722,
#                                                          'type': 'r',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-15/s/v1/if2/YK_Rx9mhvzpzS0K5K_yjY1310MEsKNmuZKQzk2nkTn0qxnJ2jo364DH_Lllperh2TSQu87t6je0HjgM_nGIk1z69.jpg?size=510x722&quality=95&type=album',
#                                                          'width': 510}],
#                                               'text': '',
#                                               'user_id': 100},
#                                     'type': 'photo'}],
#                    'date': 1656522591,
#                    'from_id': -1138759,
#                    'id': 15434,
#                    'owner_id': -1138759,
#                    'post_source': {'platform': 'iphone', 'type': 'api'},
#                    'post_type': 'post',
#                    'text': 'РАСПИСАНИЕ БОГОСЛУЖЕНИЙ.ИЮЛЬ '
#                            '2022г.☀️🌸🌹🌿🌼🌻🌹🌷🌺🌸🌼🌷🌷☀️☀️☀️'}],
#  'date': 1656777982,
#  'donut': {'is_donut': False},
#  'from_id': -82286389,
#  'hash': 'NJU5l40awS8yC0UxtMYeq_aFuhQ',
#  'id': 12496,
#  'is_favorite': False,
#  'is_pinned': 1,
#  'likes': {'can_like': 1, 'can_publish': 1, 'count': 0, 'user_likes': 0},
#  'marked_as_ads': 0,
#  'owner_id': -82286389,
#  'post_source': {'platform': 'android', 'type': 'api'},
#  'post_type': 'post',
#  'reposts': {'count': 0, 'user_reposted': 0},
#  'short_text_rate': 0.8,
#  'text': '',
#  'views': {'count': 149}}
# {'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#  'copy_history': [{'date': 1657457064,
#                    'from_id': 730205867,
#                    'id': 374,
#                    'owner_id': 730205867,
#                    'post_source': {'platform': 'android', 'type': 'api'},
#                    'post_type': 'post',
#                    'text': 'Никому не хотел бы лезьть с советами о воспитании '
#                            'их детей, они очень разнообразны по характеру даже '
#                            'в одной семье, что уж говорить о чужих. (из '
#                            'какого-то фильма: "Люблю детей. Они - как люди, '
#                            'только маленькие" 😁)\n'
#                            'Но все же послушаем общие святых отцов для '
#                            'родителей.\n'
#                            'P. S. Я бы еще дополнил цитатой прп. Паисия, что '
#                            '"родители должны дать палочку в руки Божии". Т. е. '
#                            'больше просить Его о наказании (слав. слово значит '
#                            '"научение"), чем на свой ремень надеятся.'},
#                   {'attachments': [{'photo': {'album_id': -6,
#                                               'date': 1522005239,
#                                               'has_tags': False,
#                                               'id': 456270549,
#                                               'owner_id': 219301519,
#                                               'post_id': 65829,
#                                               'sizes': [{'height': 105,
#                                                          'type': 'm',
#                                                          'url': 'https://sun1.userapi.com/sun1-99/s/v1/if1/VfMmWljoA9WeDjGfwgRjHpOIHXqTNWxacgTRYAkTr0aAtLYtEKfrHVZ6k0-3YiFglZ0Z8y85.jpg?size=130x105&quality=96&type=album',
#                                                          'width': 130},
#                                                         {'height': 105,
#                                                          'type': 'o',
#                                                          'url': 'https://sun1.userapi.com/sun1-99/s/v1/if1/VfMmWljoA9WeDjGfwgRjHpOIHXqTNWxacgTRYAkTr0aAtLYtEKfrHVZ6k0-3YiFglZ0Z8y85.jpg?size=130x105&quality=96&type=album',
#                                                          'width': 130},
#                                                         {'height': 162,
#                                                          'type': 'p',
#                                                          'url': 'https://sun1.userapi.com/sun1-99/s/v1/if1/WEIjvxUFWmUimQMGFSLBI3La06CioAdrBzUo05CpkQn_JVEy_WYddIqaH-sHUjfCCk5pQcZS.jpg?size=200x161&quality=96&type=album',
#                                                          'width': 200},
#                                                         {'height': 258,
#                                                          'type': 'q',
#                                                          'url': 'https://sun1.userapi.com/sun1-99/s/v1/if1/7pfyI_OlFs6QZZ8DJeoktbj5zJd8l3UZfvaT5WLmrZBF7fnrgvgwXlXZneG2abYV2IxArvis.jpg?size=320x258&quality=96&type=album',
#                                                          'width': 320},
#                                                         {'height': 412,
#                                                          'type': 'r',
#                                                          'url': 'https://sun1.userapi.com/sun1-99/s/v1/if1/J8TJC-RxdMFJ50jppUgg0q-WZqEzeExIFS7anRyeeVatDmtyoRhwJZnUh3TD-hv6odNomYul.jpg?size=510x412&quality=96&type=album',
#                                                          'width': 510},
#                                                         {'height': 61,
#                                                          'type': 's',
#                                                          'url': 'https://sun1.userapi.com/sun1-99/s/v1/if1/w2IVfCtegb8O4yDwaZx_1-I4J0xLCpFuz6x06dN-rcaFyMQVjVQFNdAAWRtQ76w64Nv6VCf1.jpg?size=75x61&quality=96&type=album',
#                                                          'width': 75},
#                                                         {'height': 488,
#                                                          'type': 'x',
#                                                          'url': 'https://sun1.userapi.com/sun1-99/s/v1/if1/-7vfQnw2h_PjleI2oCzg1am9mVdFOHXfgIsuISaB4XIzVAwG9jI0TEjAzuWIxpKsm15nDcK-.jpg?size=604x488&quality=96&type=album',
#                                                          'width': 604},
#                                                         {'height': 646,
#                                                          'type': 'y',
#                                                          'url': 'https://sun1.userapi.com/sun1-99/s/v1/if1/CbhOCdYlEo0hZZrNTfT1We1z1cqxpBZEjYVAafLNJllmBhAQ8_6wxZ8KfBr8LcC_WamLBKZ4.jpg?size=800x646&quality=96&type=album',
#                                                          'width': 800}],
#                                               'text': ''},
#                                     'type': 'photo'}],
#                    'date': 1526038200,
#                    'from_id': -29599237,
#                    'id': 247526,
#                    'owner_id': -29599237,
#                    'post_source': {'type': 'vk'},
#                    'post_type': 'post',
#                    'text': 'Как сделать, чтобы дети слушались. \n'
#                            ' \n'
#                            '1. "От ласки у людей бывают совсем иные глазки". \n'
#                            'Преподобный Амвросий Оптинский. \n'
#                            ' \n'
#                            '2. "Не дави на своих детей. То, что хочешь им '
#                            'сказать, говори с молитвой. Дети не слышат ушами. '
#                            'Только когда приходит Божественная благодать и '
#                            'просвещает их, они слышат то, что мы хотим им '
#                            'сказать. Когда хочешь что-нибудь сказать своим '
#                            'детям, скажи это Богородице, и Она все устроит. '
#                            'Эта молитва твоя будет, как духовная ласка, '
#                            'которая обнимет и привлечет детей. Иногда мы их '
#                            'ласкаем, а они сопротивляются, в то время как '
#                            'духовной ласке они не противятся никогда." \n'
#                            'Старец Порфирий. \n'
#                            ' \n'
#                            '3. "Больше говорите Богу о ваших детях, чем детям '
#                            'о Боге." \n'
#                            ' \n'
#                            '"Душа юного жаждет свободы, поэтому он с трудом '
#                            'принимает разнообразные советы. Вместо того чтобы '
#                            'постоянно давать ему советы и порицать за любую '
#                            'мелочь, возложи это на Христа, Богородицу и святых '
#                            'и проси Их образумить его." \n'
#                            ' \n'
#                            '"С детьми обращайтесь как с жеребятами, то '
#                            'подтягивая, то ослабляя уздечку. Когда жеребенок '
#                            'брыкается, не отпуская уздечку, ослабим ее, иначе '
#                            'же он ее порвет. Но когда он спокоен, тогда '
#                            'потянем за уздечку и поведем его, куда '
#                            'пожелаем." \n'
#                            'Старец Епифаний. \n'
#                            ' \n'
#                            '4. "Относительно Вашего ребенка, о котором мне '
#                            'пишете, я такого мнения, что суровое к нему '
#                            'отношение сделает его еще хуже. Говорите с ним о '
#                            'добром и по-доброму, и потом не давите, но '
#                            'показывайте ему, как вы огорчаетесь, что он идет '
#                            'по такому пути. Пусть явятся дела, и только дела, '
#                            'потому что ни радость не остается незамеченной, ни '
#                            'печаль. Вы исполняйте свои обязанности, давая '
#                            'советы, а потом доверьте Вашего ребенка Богу." \n'
#                            ' \n'
#                            '"Я думаю, что труд Ваш будет иметь большие '
#                            'результаты, если будет сопряжен с молитвой. Когда '
#                            'Вы страдаете от бесчинств ребенка и давите на '
#                            'него, результатов не будет, ибо ребенок '
#                            'взбудоражен плотью и нападениями лукавого, '
#                            'которому платит дань..." \n'
#                            ' \n'
#                            '"Старайтесь, насколько можете, не отталкивать от '
#                            'себя ребенка, как я уже сказал, чтобы он не порвал '
#                            'привязи и не убежал из семьи, потому что потом '
#                            'может выйти так, что он не захочет приблизиться '
#                            'из-за эгоизма, и Вы его совсем потеряете..." \n'
#                            ' \n'
#                            '"Молитесь, и я буду молиться, и благой Бог поможет '
#                            'и Вашему ребенку, и всем детям нашего мира." \n'
#                            'Старец Паисий Святогорец. \n'
#                            ' \n'
#                            '5. "Детей вразумлять есть долг родителей, — стало '
#                            'и ваш. И бояться чего? Слово любовное никогда не '
#                            'раздражает. Командирское только никакого плода не '
#                            'производит. Что-бы детям благословил Господь '
#                            'избежать опасностей, надо молиться и день и ночь. '
#                            'Бог милостив! Он имеет много средств '
#                            'предотвращать, — какие нам и в голову не придут. '
#                            'Бог всем правит. Он мудрый, всеблагий и всемощный '
#                            'Правитель. И мы принадлежим к Царству Его. Чего же '
#                            'унывать? Он не даст Своих в обиду. Об одном надо '
#                            'заботиться, — как бы не оскорбить Его, и как бы Он '
#                            'не вычеркнул вас из числа Своих." \n'
#                            'Святитель Феофан Затворник. \n'
#                            ' \n'
#                            '"Не всегда штраф... Почаще — уговаривание. Это '
#                            'мягче и прочнее. Строгость непрестанная жестка и '
#                            'безотрадна. Поблажки, конечно, не следует '
#                            'допускать, но и строгость надо растворять теплотой '
#                            'любви..." \n'
#                            'Святитель Феофан Затворник. \n'
#                            ' \n'
#                            '6. "Хорошо, если бы наши дети были лучше нас. Но '
#                            'тут нужно быть осторожным, как бы не перегнуть '
#                            'палку. Я помню, как ко мне обратился сын: "Папа, я '
#                            'хочу слона". Я говорю сыну, что слон ведь много '
#                            'ест, его надо кормить. Ты для тренировки '
#                            'постарайся для всех накрывать на стол. Через два '
#                            'дня сын сказал: "Нет, пап, слона не нужно, он '
#                            'очень много ест" Он сам пришел к выводу, что слона '
#                            'хорошо бы иметь, но он очень много ест. Старайтесь '
#                            'не создавать особых конфликтов, чтобы не разрушить '
#                            'сердечных отношений с детьми. Когда мои дети были '
#                            'еще маленькие, мне один монах архимандрит сказал: '
#                            '"Старайся, чтобы дети тебя любили, тогда ты '
#                            'сможешь все с ними сделать". Как вы будете этого '
#                            'добиваться, это ваше дело. Больше того, это '
#                            'относится не только к детям. Вы сможете с любым '
#                            'человеком сделать что угодно (я имею в виду только '
#                            'хорошее, конечно), если между вами будет любовь. '
#                            'Всем известен пример нашего соотечественника '
#                            'Александра Васильевича Суворова. Его солдаты '
#                            'любили и делали невозможное на поле боя. Если в '
#                            'основе семейных отношений лежит любовь, то все '
#                            'возможно, и это нужно помнить всегда. Что бы вы ни '
#                            'делали в воспитании, старайтесь не потерять '
#                            'чувство любви. Был такой батюшка, к нему пришел '
#                            'один человек и говорит: "Батюшка, ну что делать, '
#                            'когда человек пристает к тебе?" Он говорит: "Не '
#                            'обращай внимания". — "А он еще пристает и '
#                            'пристает". — "Ну, прости ему". — "Но он еще '
#                            'пристает". — "Ну тогда с большой любовью задай '
#                            'ему". \n'
#                            'Протоиерей Валериан Кречетов'}],
#  'date': 1657470213,
#  'donut': {'is_donut': False},
#  'from_id': -82286389,
#  'hash': 'JqI9vJrC3eyFjHBLR9AE4azN9y8',
#  'id': 12512,
#  'is_favorite': False,
#  'likes': {'can_like': 1, 'can_publish': 1, 'count': 0, 'user_likes': 0},
#  'marked_as_ads': 0,
#  'owner_id': -82286389,
#  'post_source': {'platform': 'android', 'type': 'api'},
#  'post_type': 'post',
#  'reposts': {'count': 0, 'user_reposted': 0},
#  'short_text_rate': 0.8,
#  'text': '',
#  'views': {'count': 250}}
# {'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#  'copy_history': [{'attachments': [{'photo': {'access_key': '902fbecef2a37dceea',
#                                               'album_id': -7,
#                                               'date': 1657084434,
#                                               'has_tags': False,
#                                               'id': 457251225,
#                                               'owner_id': 30166354,
#                                               'sizes': [{'height': 56,
#                                                          'type': 's',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/bR8Tj7CORqcWv6xn33Dn35H20azOOhB5kRV8gFL5JSn1OW7KEaGpZwM14CNRmNm8GNE_SwfJdAtckc0VTlLOeV9R.jpg?size=75x56&quality=95&type=album',
#                                                          'width': 75},
#                                                         {'height': 97,
#                                                          'type': 'm',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/IFSpjF1kDeeDcBOJGRDkV8jRVck6YnCZIC8igjVR0bOwigujjvPqwsIMswSQX5CDJJJFJCmwmVy51eMMp2xuVEXe.jpg?size=130x97&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 453,
#                                                          'type': 'x',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/xUM32aI_IVza_6dEURNGFI1Vhvg9h954tRQXnhrW-vcIplEMYoRy3OM_4YM17lbaTv1ulkxEttTTDWujrc4DaPDv.jpg?size=604x453&quality=95&type=album',
#                                                          'width': 604},
#                                                         {'height': 605,
#                                                          'type': 'y',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/-afxN2RtxOnxzj7bEY6d_bqUzzn5ltVHEpQSEhtY6ch0etit5SST5UouNnYwyvXDiev5a1y7bETgMcXXK2PULrCO.jpg?size=807x605&quality=95&type=album',
#                                                          'width': 807},
#                                                         {'height': 960,
#                                                          'type': 'z',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/LK0ZMk2LcPMkBgC-uCn4Cf88neKESq3bFp9PdCxFqg2EMvmefGp4Kl9rbe3yfLsSBBjbEi2mk_QeIbuHGkKSplvY.jpg?size=1280x960&quality=95&type=album',
#                                                          'width': 1280},
#                                                         {'height': 1200,
#                                                          'type': 'w',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/TzdmkHu-B_KfI_Jz5UFR95OZQHGrNeExELJnSMoswqgg2XySGfP-RoTa5wrDAUI8AaIhRoYj9vo0Sz59Fnnm-qP1.jpg?size=1600x1200&quality=95&type=album',
#                                                          'width': 1600},
#                                                         {'height': 97,
#                                                          'type': 'o',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/IFSpjF1kDeeDcBOJGRDkV8jRVck6YnCZIC8igjVR0bOwigujjvPqwsIMswSQX5CDJJJFJCmwmVy51eMMp2xuVEXe.jpg?size=130x97&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 150,
#                                                          'type': 'p',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/FszBF6aFwzSXX-YXhAOshboqcUFcnzzjMrEQuHQiWDcSj-MqjteUJq-b38gLoF9r6SnThKEptvNy0bF-OgdWS47P.jpg?size=200x150&quality=95&type=album',
#                                                          'width': 200},
#                                                         {'height': 240,
#                                                          'type': 'q',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/FrD7GLGp8vhhZOTcDCk8Xxd01GZEG7x3plRd7gFC_-QIZGF2hvMMoaxqshpNi-f7nuO7Ed2GveENdDdGtkwfM-Vj.jpg?size=320x240&quality=95&type=album',
#                                                          'width': 320},
#                                                         {'height': 382,
#                                                          'type': 'r',
#                                                          'url': 'https://sun1.userapi.com/sun1-98/s/v1/if2/bgPcQRiEAnz_U7Ztf2LkhAkZVmFNZBm_gcDa8KsZEkUonCQbdMbrB95dxJV48Hw-HaAJaY-JGrGzY2kM9fY_AA5N.jpg?size=510x382&quality=95&type=album',
#                                                          'width': 510}],
#                                               'text': ''},
#                                     'type': 'photo'},
#                                    {'photo': {'access_key': 'f578927aa79b7b436e',
#                                               'album_id': -7,
#                                               'date': 1657084435,
#                                               'has_tags': False,
#                                               'id': 457251226,
#                                               'owner_id': 30166354,
#                                               'sizes': [{'height': 56,
#                                                          'type': 's',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/lYyjJnPjR1IAFPwCGbbK6Wk378KPnVGYLZfaPIcipA3hWiLfIcdUF72JlFqBV1Y-3OapxjBb8ZZqAtVtw0074CIV.jpg?size=75x56&quality=95&type=album',
#                                                          'width': 75},
#                                                         {'height': 98,
#                                                          'type': 'm',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/SI5pR4QNekDf9LJ-v6NxLisYArF9zWdiHstS0RuWS3R5Mg1fQFL2bGLtj3T5QHPJLcJdDvajWu-fckSqEyYMwCxs.jpg?size=130x98&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 454,
#                                                          'type': 'x',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/92j-L6QPvesIUfnyv-2J55LGYTZU7rmypyWIXFcASBsKWMR5QzNRb1OL7LCrcCLm7OzR2F4LIXg-lRifzcMBZFMX.jpg?size=604x454&quality=95&type=album',
#                                                          'width': 604},
#                                                         {'height': 606,
#                                                          'type': 'y',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/_TnVU_bTYjwG_lzYeRypSb-_uts3j6WbJYRSw137XveFlW4d-0W6vsWzkU2gRD-p2exYlJ55oO0eWy6SqtAuuL6N.jpg?size=807x606&quality=95&type=album',
#                                                          'width': 807},
#                                                         {'height': 962,
#                                                          'type': 'z',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/YA52Tc1CO_GMb43ZCAjttAHWdJrvdJB1OviGAirstJF902MUlJ-kZ0qiHv0TWylizJeWxGXq5aPpQRezSZKDz8M8.jpg?size=1280x962&quality=95&type=album',
#                                                          'width': 1280},
#                                                         {'height': 1202,
#                                                          'type': 'w',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/1JnuD_a6so9wqs0EoEbsl2pdlFkcS6qyAW24pNapPrE4Fxc5TPvpRrx8Jupnsh9XxgsG6Jq8shXe3S1Ryrf2Hgts.jpg?size=1600x1202&quality=95&type=album',
#                                                          'width': 1600},
#                                                         {'height': 98,
#                                                          'type': 'o',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/SI5pR4QNekDf9LJ-v6NxLisYArF9zWdiHstS0RuWS3R5Mg1fQFL2bGLtj3T5QHPJLcJdDvajWu-fckSqEyYMwCxs.jpg?size=130x98&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 150,
#                                                          'type': 'p',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/brse1Jh3FJbLF0UQ1Ss7EOAFpcNX-GZ9z92mxujwAN_wmoGIohLeC4DOChhGsut4cTjclAdKaxiCftJZ8AmAO6sk.jpg?size=200x150&quality=95&type=album',
#                                                          'width': 200},
#                                                         {'height': 240,
#                                                          'type': 'q',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/bbDQuyxs_s-g5_UyY031u7NMGrx00PUGssZM0bFbsVOYDqwsdMJehFbA2_l0Ee8GUEvf7UKAeC8lHe8qHjMHoZD1.jpg?size=320x240&quality=95&type=album',
#                                                          'width': 320},
#                                                         {'height': 383,
#                                                          'type': 'r',
#                                                          'url': 'https://sun1.userapi.com/sun1-91/s/v1/if2/AIYrgfTC-jZEMIpChNyR8gUohSSsTS1zj1frbq0B97_NJgoIBCzcpF6vA5MDrOpFVGCFuLxlMjh_sH0CrFkTEDNj.jpg?size=510x383&quality=95&type=album',
#                                                          'width': 510}],
#                                               'text': ''},
#                                     'type': 'photo'},
#                                    {'photo': {'access_key': 'e8bbc0f60c85c84e04',
#                                               'album_id': -7,
#                                               'date': 1657084437,
#                                               'has_tags': False,
#                                               'id': 457251227,
#                                               'owner_id': 30166354,
#                                               'sizes': [{'height': 56,
#                                                          'type': 's',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/8RDWmVng4feQoRHjOTrnBkDkGdKUlWWhEX7Vf-A9kakMW_5crR51JG9FSyKXs1bXEHgfI06n-xA0SVc30Yil5R9i.jpg?size=75x56&quality=95&type=album',
#                                                          'width': 75},
#                                                         {'height': 97,
#                                                          'type': 'm',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/7l-2JhLBxJaXaCsmetqmCqv9d1Pm8waYzn9XgRTRTCKzNoGlnYdfBeZG_93HTQ63X_zf5N8UIrbi9GQkhmCJWGy8.jpg?size=130x97&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 453,
#                                                          'type': 'x',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/QtGYaV1ZnULB35Mm0fcgbwgCpzVZa1iqCygNyeDZ781KyAoNmFw4fz6EdFv_y1nFYgptcVt4grhRCoYfIQlOdVyu.jpg?size=604x453&quality=95&type=album',
#                                                          'width': 604},
#                                                         {'height': 605,
#                                                          'type': 'y',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/EISQAsowB_5BbKvZXwpma09iyYv2xOeqWXBVD3xrx8JWX9ZVxvA5LNCFyFo_SlHNtTd6Dri-mMM4Qousl0Wq4wBb.jpg?size=807x605&quality=95&type=album',
#                                                          'width': 807},
#                                                         {'height': 960,
#                                                          'type': 'z',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/6B63y0VAkLY8XJTQr70Qqy5pc0QT_iq-IUEFeRhspuikaLpS65Ahy5b_Zc2uFzJLo-s4_nV5GJCJ4a_eRvnOTMIA.jpg?size=1280x960&quality=95&type=album',
#                                                          'width': 1280},
#                                                         {'height': 1200,
#                                                          'type': 'w',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/h-Ut5Vf4PJHBUAuKN3gNGg0podvT0zEK9gMy-gg63p-hI_AMZOEPPlxFkVJRpeS1iL42uwaUpu68QC-mmuiAetyA.jpg?size=1600x1200&quality=95&type=album',
#                                                          'width': 1600},
#                                                         {'height': 97,
#                                                          'type': 'o',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/7l-2JhLBxJaXaCsmetqmCqv9d1Pm8waYzn9XgRTRTCKzNoGlnYdfBeZG_93HTQ63X_zf5N8UIrbi9GQkhmCJWGy8.jpg?size=130x97&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 150,
#                                                          'type': 'p',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/Cii0LC2vx0dkskPgQIz51mDuMWbRvG03PIZ4Q_4A8vbqxlFBf-Cvhzlg6xTBhFFHMWr_zxTWqOZZBEibZABC5Aj2.jpg?size=200x150&quality=95&type=album',
#                                                          'width': 200},
#                                                         {'height': 240,
#                                                          'type': 'q',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/AdpwToZ_ORciQw8GaJwB4Cp85GSx0-SMZz8QgidmErXc0D-Pct1CC4SWPjeSC4hUp8W4icrl3utzIdozQwVWHaVy.jpg?size=320x240&quality=95&type=album',
#                                                          'width': 320},
#                                                         {'height': 382,
#                                                          'type': 'r',
#                                                          'url': 'https://sun9-west.userapi.com/sun9-39/s/v1/if2/4AJ1sXE5RJehnUXtqHgz34WJvYBdhbLdLN6yxg5FVfCSCzYB2uSaBfDWZBM6-3d3p0V2TcRRlTIzoVn1nr8dCjv8.jpg?size=510x382&quality=95&type=album',
#                                                          'width': 510}],
#                                               'text': ''},
#                                     'type': 'photo'},
#                                    {'type': 'video',
#                                     'video': {'access_key': '06dbeb1fafb13baeb4',
#                                               'can_add': 1,
#                                               'can_add_to_faves': 1,
#                                               'can_comment': 1,
#                                               'can_like': 1,
#                                               'can_repost': 1,
#                                               'can_subscribe': 1,
#                                               'comments': 1,
#                                               'date': 1657084437,
#                                               'description': '',
#                                               'duration': 98,
#                                               'first_frame': [{'height': 405,
#                                                                'url': 'https://i.mycdn.me/getVideoPreview?id=2786351385170&idx=0&type=39&tkn=FU3xgrtHAgbiq8w2WXNTa1HQXT4&fn=vid_f',
#                                                                'width': 720},
#                                                               {'height': 270,
#                                                                'url': 'https://i.mycdn.me/getVideoPreview?id=2786351385170&idx=0&type=39&tkn=FU3xgrtHAgbiq8w2WXNTa1HQXT4&fn=vid_md',
#                                                                'width': 480},
#                                                               {'height': 135,
#                                                                'url': 'https://i.mycdn.me/getVideoPreview?id=2786351385170&idx=0&type=39&tkn=FU3xgrtHAgbiq8w2WXNTa1HQXT4&fn=vid_d',
#                                                                'width': 240},
#                                                               {'height': 72,
#                                                                'url': 'https://i.mycdn.me/getVideoPreview?id=2786351385170&idx=0&type=39&tkn=FU3xgrtHAgbiq8w2WXNTa1HQXT4&fn=vid_sm',
#                                                                'width': 128},
#                                                               {'height': 720,
#                                                                'url': 'https://i.mycdn.me/getVideoPreview?id=2786351385170&idx=0&type=39&tkn=FU3xgrtHAgbiq8w2WXNTa1HQXT4',
#                                                                'width': 1280},
#                                                               {'height': 540,
# ...
#                            'может, и поймем когда-нибудь. \n'
#                            ' \n'
#                            'Да. Не повторится многое. Но оно было. И оно — '
#                            'наше. И нашим останется. \n'
#                            'Слезами ли, счастьем, болью, с которой жить. Но — '
#                            'нашим. Жалей. Не о прошлом, не о несбывшемся, '
#                            'жалей тех, кому, видит Бог, много хуже, чем тебе. '
#                            'И прости. Всех тех, кто обидел, предал, оскорбил — '
#                            'так много чего \n'
#                            'можно написать, кто кому сделал плохого. Это '
#                            'вечная борьба добра и зла. И кто делал то или '
#                            'другое — по сути, не разобрать. У каждого своя '
#                            'правда. \n'
#                            'Только не плачь. И ничего не бойся. Иди и делай. И '
#                            'все — получится. \n'
#                            '\n'
#                            'Доктор Лиза'}],
#  'date': 1656016509,
#  'donut': {'is_donut': False},
#  'from_id': -82286389,
#  'hash': 'xr-QoRu5uOhYSXCEHgK6t_bwyHM',
#  'id': 12491,
#  'is_favorite': False,
#  'likes': {'can_like': 1, 'can_publish': 1, 'count': 2, 'user_likes': 0},
#  'marked_as_ads': 0,
#  'owner_id': -82286389,
#  'post_source': {'platform': 'android', 'type': 'api'},
#  'post_type': 'post',
#  'reposts': {'count': 0, 'user_reposted': 0},
#  'short_text_rate': 0.8,
#  'text': '',
#  'views': {'count': 166}}
# {'comments': {'can_post': 1, 'count': 0, 'groups_can_post': True},
#  'copy_history': [{'attachments': [{'photo': {'access_key': 'b987ca8cfd66e18fd3',
#                                               'album_id': -7,
#                                               'date': 1655650156,
#                                               'has_tags': False,
#                                               'id': 457245260,
#                                               'owner_id': -1138759,
#                                               'post_id': 15389,
#                                               'sizes': [{'height': 75,
#                                                          'type': 's',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-31/s/v1/if2/lwRV6QDUCKGo7v_uwvlA_NbdlqqB3OIGSss7jW7HdwdJynPWJAFP1rbFffvyDVuibwG-DlTgKhtMjKoUqgbZ6pFq.jpg?size=53x75&quality=95&type=album',
#                                                          'width': 53},
#                                                         {'height': 130,
#                                                          'type': 'm',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-31/s/v1/if2/qH0yg_QjEpvRokAFh04fy6KH50vj7YLZuW0U5HpJj8GMQrsKDRMFR7V0yx7oj1sPaw_U0LZ5XF2QXSSyj8y0v7ji.jpg?size=92x130&quality=95&type=album',
#                                                          'width': 92},
#                                                         {'height': 604,
#                                                          'type': 'x',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-31/s/v1/if2/CP58XCBFdNkFQNc3HmyxkEwFtxHt1DjPDkCiJ9Vx2dWM-Zdo2rtYBIQFT5Y1qjTsxIB7-eH1vSEPCbX9qnTuU2F3.jpg?size=427x604&quality=95&type=album',
#                                                          'width': 427},
#                                                         {'height': 807,
#                                                          'type': 'y',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-31/s/v1/if2/lcJZoqYqKmqNVi0I29DpZDR5wRd28rMxShnnrTHrX5NSpHqv2JQj5RyH1p-JqZw6L2EriuBLEYxQwjUcC3oppPOT.jpg?size=571x807&quality=95&type=album',
#                                                          'width': 571},
#                                                         {'height': 1024,
#                                                          'type': 'z',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-31/s/v1/if2/ypl-JWCxCcjTCxwkQdmnD5AjhA0pliqZJZQVV42Aex4mp3LNn3HeI7UUdumIIlbr2XK-_PEsr9HzIqmHxuinLPRg.jpg?size=724x1024&quality=95&type=album',
#                                                          'width': 724},
#                                                         {'height': 184,
#                                                          'type': 'o',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-31/s/v1/if2/XWbDzeM7kySI7VDEtX2eo004pBy8SrMOrxcWLdxaRxZH7xi2DYkLkZjE5Wa6kx9X0z5rg6SJqq3AkVKK1M5g1mFh.jpg?size=130x184&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 283,
#                                                          'type': 'p',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-31/s/v1/if2/--ZjM9-o_yiAaogFjPuezEv9t_mV6JidArqnyGQdI6zZbTzMauItKIEfJMG23HJeoERcaIlxa6K1wDW1U5GiRsQC.jpg?size=200x283&quality=95&type=album',
#                                                          'width': 200},
#                                                         {'height': 453,
#                                                          'type': 'q',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-31/s/v1/if2/EFvgf6Wthm_U0OSpGWaqV3BhuJZ3ZnaF8wem9pwPrLbHZBX_rFQYDD9yYgsoaghopMu3b1xGSSi_tCZ1UNSr6Hru.jpg?size=320x453&quality=95&type=album',
#                                                          'width': 320},
#                                                         {'height': 721,
#                                                          'type': 'r',
#                                                          'url': 'https://sun9-east.userapi.com/sun9-31/s/v1/if2/kmS6dINiLJXW10MMsUBGA_ZJ8VXrrTsbfmOmaHVNs4WKsEygZFIPFPIKQH4Q4tT-Vg8uSdinV3V2Gq3nhvyfF49j.jpg?size=510x721&quality=95&type=album',
#                                                          'width': 510}],
#                                               'text': '',
#                                               'user_id': 100},
#                                     'type': 'photo'}],
#                    'date': 1655650156,
#                    'from_id': -1138759,
#                    'id': 15389,
#                    'owner_id': -1138759,
#                    'post_source': {'platform': 'iphone', 'type': 'api'},
#                    'post_type': 'post',
#                    'text': ''}],
#  'date': 1656010383,
#  'donut': {'is_donut': False},
#  'from_id': -82286389,
#  'hash': 'KS7FWDVEbuFtlZ_W82OgkCvEBdg',
#  'id': 12489,
#  'is_favorite': False,
#  'likes': {'can_like': 1, 'can_publish': 1, 'count': 1, 'user_likes': 0},
#  'marked_as_ads': 0,
#  'owner_id': -82286389,
#  'post_source': {'type': 'vk'},
#  'post_type': 'post',
#  'reposts': {'count': 1, 'user_reposted': 0},
#  'short_text_rate': 0.8,
#  'text': '',
#  'views': {'count': 117}}
# {'comments': {'can_post': 1, 'count': 2, 'groups_can_post': True},
#  'copy_history': [{'attachments': [{'photo': {'access_key': 'a5a93814b3de68b93e',
#                                               'album_id': -7,
#                                               'date': 1655624851,
#                                               'has_tags': False,
#                                               'id': 457247538,
#                                               'owner_id': -100931612,
#                                               'post_id': 121259,
#                                               'sizes': [{'height': 75,
#                                                          'type': 's',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/9bCkG8MWSFcRrIsmRZobuCniu8BXSRdon9K3H7Noup5oNzrgf-7vhhgyh95y8VR0GSZGlDK6ynKc-Nsi2Pbgq8Fq.jpg?size=49x75&quality=95&type=album',
#                                                          'width': 49},
#                                                         {'height': 130,
#                                                          'type': 'm',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/cvRr5BTmfe1XPGm1Os30KGgYcTBIHDqPoPCLwCIOOVlkw10byY3-1i2MA_D_waISYerBNVBFFnzAeLErROIgSF76.jpg?size=85x130&quality=95&type=album',
#                                                          'width': 85},
#                                                         {'height': 604,
#                                                          'type': 'x',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/OgYJHg_nYT3DmQ0Uuucm7LOZ6gXltxjd9m6ZRi5uH3Rn9hFIxY4q0Cs00aUpu1oHMmN9EjHeGJFDSx1s8udFnoO3.jpg?size=394x604&quality=95&type=album',
#                                                          'width': 394},
#                                                         {'height': 807,
#                                                          'type': 'y',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/DksfKlfLtjoi8BMiUGt1yH_xLAFrtJzAi55DV_FQtY6jS8XWPxIFKv-Zggff2yPHo2uYZNp68a_kIpd0dQ7YMmXn.jpg?size=526x807&quality=95&type=album',
#                                                          'width': 526},
#                                                         {'height': 1080,
#                                                          'type': 'z',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/M66TxCV9GMPOnmUyhVCr1DCdFqgt4Xk1rS3E0CPl4zQ1zAjHOf-E_doqMFapZ20yrXF8jqxTUa2vvqL2XHuzyZsg.jpg?size=704x1080&quality=95&type=album',
#                                                          'width': 704},
#                                                         {'height': 1653,
#                                                          'type': 'w',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/yYsKxq8TyLcuhkZl0hQWkDNWYHSN65tS3O6c3NWK2CKbY-D7HuFqorXyMnJltQ4Z83hVDwPatBuoNLMjWyQDlETI.jpg?size=1078x1653&quality=95&type=album',
#                                                          'width': 1078},
#                                                         {'height': 199,
#                                                          'type': 'o',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/nDGMa54qNeaZ6ZMbyYB8SdBtgmeDvPl7cUwF9AoPsAGn4vhf9FN7sJF61kJkfIb8slZlpHiJI0Nukn_YBmlkDfSO.jpg?size=130x199&quality=95&type=album',
#                                                          'width': 130},
#                                                         {'height': 307,
#                                                          'type': 'p',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/YX8fyRlsUhDzUvBOkx3VG9tnPtYs-RqhiDpd77j4aex__LUOlJZgRuuMFB0oodq7JLKRl7PICiLYm_TJHX_y3yTp.jpg?size=200x307&quality=95&type=album',
#                                                          'width': 200},
#                                                         {'height': 491,
#                                                          'type': 'q',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/n1OnwvxYuMUEUSZ2AvpHAjJapO1UpR6_n4OlnilXCZuPXA4_4nXYJ_Qx78LbNSBdqfgchMV8wi06zRxKX16vfU62.jpg?size=320x491&quality=95&type=album',
#                                                          'width': 320},
#                                                         {'height': 782,
#                                                          'type': 'r',
#                                                          'url': 'https://sun1.userapi.com/sun1-20/s/v1/if2/J6eDrxy-Wo8IwxCvAiNtwgFhH9raD0pmj4XNv818Vf_KbYQvNC-4Z6aUseOyHy0EWyNexMXBKXTOnTB41pJakHB_.jpg?size=510x782&quality=95&type=album',
#                                                          'width': 510}],
#                                               'text': '',
#                                               'user_id': 100},
#                                     'type': 'photo'}],
#                    'date': 1655657700,
#                    'from_id': -100931612,
#                    'id': 121259,
#                    'owner_id': -100931612,
#                    'post_source': {'type': 'vk'},
#                    'post_type': 'post',
#                    'text': 'Верующие лучше других?\n'
#                            '\n'
#                            'Верующие семьи очень часто кажутся волшебными, но '
#                            'реальность совсем другая, даже если ты священник. '
#                            'Вот моя жена из Нарнии, а я тельмаринец. В Нарнии '
#                            'не все верны Аслану, злая колдунья всегда где-то '
#                            'рядом. Даже у волшебных девочек и мальчиков есть '
#                            'свои тёмные стороны.\n'
#                            ' \n'
#                            ' Почему, кому-то кажется, что злой рок разрушает '
#                            'их семейное счастье?\n'
#                            ' \n'
#                            ' Отбросьте иллюзии, что у верующих жизнь в '
#                            'шоколадной сказке. К сожалению, даже в семьях '
#                            'священников случаются несчастья. Матушки и батюшки '
#                            'тоже не всегда ладят. Частенько после семинарии '
#                            'рано женятся, толком не узнав друг друга. Да и '
#                            'сватовство ещё существует, особенно в семьях '
#                            'потомственных священнослужителей.\n'
#                            ' \n'
#                            ' Я видел много таких семей, в которых жена с мужем '
#                            'дома как чужие. Она звонит ему с претензиями, '
#                            'когда он задерживается, требует денег и пилит. Он '
#                            'огрызается, прогоняет от себя детей, а друзьям '
#                            'рассказывает, какая она стерва или делает вид, что '
#                            'всё хорошо. Одним страшно выносить сор из избы, а '
#                            'другие сплетничают о своих половинках своим '
#                            'друзьям и подругам.\n'
#                            ' \n'
#                            ' Может, им просто не повезло друг с другом?\n'
#                            ' \n'
#                            ' Некоторым кажется, что у всех непременно должно '
#                            'быть дома плохо, как в популярных сериальчиках, '
#                            'ведь тогда можно ничего не делать. Думаете, '
#                            'семейное счастье - это лотерея или провидение '
#                            'Божье? Одним повезло, а другим нет? В Браке живут '
#                            'вместе или по отдельности. Если вы вместе, станете '
#                            'родными, если каждый сам по себе, то так и '
#                            'останетесь одиночками.\n'
#                            ' \n'
#                            ' Даже в сказках Льюиса не бывает всё хорошо, но '
#                            'эти сказки никак не связаны с промыслом Божьим, а '
#                            'с тараканами в твоей голове.\n'
#                            '\n'
#                            '[club100931612|Священник Николай Бабкин]'}],
#  'date': 1655977212,
#  'donut': {'is_donut': False},
#  'from_id': -82286389,
#  'hash': '2zYilwnM63Y7_UTJF_OFKRFuHBo',
#  'id': 12487,
#  'is_favorite': False,
#  'likes': {'can_like': 1, 'can_publish': 1, 'count': 5, 'user_likes': 0},
#  'marked_as_ads': 0,
#  'owner_id': -82286389,
#  'post_source': {'platform': 'android', 'type': 'api'},
#  'post_type': 'post',
#  'reposts': {'count': 0, 'user_reposted': 0},
#  'short_text_rate': 0.8,
#  'text': '',
#  'views': {'count': 394}}

# %%
# TEST: check how to extract month
from datetime import datetime
from collections import defaultdict

timestamp = 1630510421
dt_object = datetime.fromtimestamp(timestamp)

print("dt_object =", dt_object.strftime("%m"))  # "%Y"

months = defaultdict(list)
for item in response["response"]["items"]:
    timestamp = item["date"]
    dt_object = datetime.fromtimestamp(timestamp)
    year = dt_object.strftime("%Y")
    month = dt_object.strftime("%m")
    months[str(year) + str(month)].append(item["id"])

print(months, response["response"]["count"])
posts_per_month = sum([len(val) for val in months.values()]) / len(months)
print(posts_per_month)
# Out:
# dt_object = 09
# defaultdict(<class 'list'>, {'202109': [10], '202108': [9, 8, 5, 4], '202106': [3]}) 6
# 2.0

# %% [markdown]
# 3. Number of likes on each post (then get a mean) &
#
# 4. Number of comments on each post (then get a mean) `wall.getComments`
#
# Likes are counted in the method `wall.get` above `response[0]["likes"]["count"]`. Also I can get there number of comments `response[0]["comments"]["count"]`, number of reposts `response[0]["reposts"]["count"]`, number of total VIEWS of the post `response[0]["views"]["count"]`.

# %% [markdown]
# ### Check links

# %%
ngos_with_vk = all_socials[~all_socials["vk"].isnull()]

# %%
ngos_with_vk.head()
# Out:
#                                url  \
# 4   http://intellect-foundation.ru
# 12   http://рбоонадежда47регион.рф
# 14         http://securitymedia.ru
# 18     http://ecology-tatarstan.ru
# 22               http://dvbfond.ru
#
#                                                 fb  \
# 4                                              NaN
# 12                                             NaN
# 14  https://www.facebook.com/industriabezopasnosti
# 18                                             NaN
# 22                                             NaN
#
#                                                    vk  \
# 4                 https://vk.com/intellect.foundation
# 12  https://vk.com/pomoschsemie.luga?w=app5619682_...
# 14                       https://vk.com/securitymedia
# 18                     https://vk.com/public173749519
# 22                    https://vk.com/fonddobrovoblago
#
#                                                  ig   ok  \
# 4        https://instagram.com/intellect.foundation  NaN
# 12                                              NaN  NaN
# 14                                              NaN  NaN
# 18                                              NaN  NaN
# 22  https://www.instagram.com/kirillpetrovhelp_sma/  NaN
#
#                                               youtube tiktok
# 4                                                 NaN    NaN
# 12                                                NaN    NaN
# 14                                                NaN    NaN
# 18                                                NaN    NaN
# 22  https://www.youtube.com/channel/UCiwOoMTRTDMa2...    NaN

# %%
re.search(r'(.+)\?', ngos_with_vk.iloc[1]["vk"]).group(1)
# Out:
# 'https://vk.com/pomoschsemie.luga'

# %%
ngos_with_vk["vk"] = ngos_with_vk["vk"].apply(lambda x: re.search(r'(.+)\?', x).group(1) if "?" in x else x)
# Out:
# d:\python371\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
ngos_with_vk.head(50)
# Out:
#                                      url  \
# 4         http://intellect-foundation.ru
# 12         http://рбоонадежда47регион.рф
# 14               http://securitymedia.ru
# 18           http://ecology-tatarstan.ru
# 22                     http://dvbfond.ru
# 24   http://адвокат-юрист-красногорск.рф
# 29                      http://nf2217.ru
# 32               http://nko-pazvitiye.ru
# 33                 http://polzamarket.ru
# 35                   http://добрубыть.рф
# 37                    https://nko-new.ru
# 39                    http://bf-ansar.ru
# 40                      http://lendir.ru
# 45                     http://in-ural.ru
# 48               http://rukapomoshi03.ru
# 55                  http://dobropoint.ru
# 61                   http://teatrsela.ru
# 63            http://istoria1projecta.ru
# 68     http://дни-предпринимательства.рф
# 70                      http://gm-edu.ru
# 72                 http://нко-спартак.рф
# 75                    http://art-omir.ru
# 78                    http://familybf.ru
# 79                    http://klubsila.ru
# 81                http://avangard-ano.ru
# 84                    http://hopefund.ru
# 85                    http://fc-pskov.ru
# 87                   http://rkfavorit.ru
# 94            http://algorithm-school.ru
# 95                   http://oncomayak.ru
# 96                  http://rekigorodu.ru
# 98                   http://cleaninet.ru
# 103              http://дерево-сказок.рф
# 106                   http://bon-bons.ru
# 120         http://protivnikakogomera.ru
# 122                  http://filirugby.ru
# 123                    http://autside.ru
# 124                  http://prirodada.ru
# 130                   http://uldosaaf.ru
# 131                 http://ithubgroup.ru
# 132                    http://mipkpir.ru
# 142                       http://uipk.ru
# 146                http://anoviktoria.ru
# 154                 http://kupnokreml.ru
# 155                     http://пайтон.рф
# 161          http://visit-kaliningrad.ru
# 162                      http://bflot.ru
# 168               http://ano-propotok.ru
# 172                   http://vitakids.ru
# 173               http://special-care.ru
#
#                                                     fb  \
# 4                                                  NaN
# 12                                                 NaN
# 14      https://www.facebook.com/industriabezopasnosti
# 18                                                 NaN
# 22                                                 NaN
# 24                                                 NaN
# 29   https://www.facebook.com/МРОО-помощи-пациентам...
# 32                                                 NaN
# 33              https://www.facebook.com/u.bioproduct/
# 35                                                 NaN
# 37             https://www.facebook.com/groups/nkonew/
# 39                                                 NaN
# 40    https://www.facebook.com/groups/3207237442717865
# 45                                                 NaN
# 48                                                 NaN
# 55                                                 NaN
# 61                  https://www.facebook.com/teatrsela
# 63                                                 NaN
# 68                 https://www.facebook.com/agpb24.ru/
# 70                           https://www.facebook.com/
# 72                                                 NaN
# 75                                                 NaN
# 78      https://www.facebook.com/Семья-103179345456877
# 79                                                 NaN
# 81                                                 NaN
# 84                           https://www.facebook.com/
# 85                                                 NaN
# 87                                                 NaN
# 94           https://www.facebook.com/schoolalgorithm/
# 95                                                 NaN
# 96             https://www.facebook.com/rivermakers18/
# 98                                                 NaN
# 103                                                NaN
# 106             https://www.facebook.com/bonbons8marta
# 120                  https://www.facebook.com/TimeWeb/
# 122                https://www.facebook.com/filirugby/
# 123              https://www.facebook.com/autsidefond/
# 124  https://www.facebook.com/profile.php?id=100066...
# 130                  https://www.facebook.com/uldosaaf
# 131                 https://www.facebook.com/ithub.ru/
# 132                                                NaN
# 142                 https://www.facebook.com/uipk21vek
# 146                                                NaN
# 154                https://www.facebook.com/kupnokreml
# 155                https://www.facebook.com/kupnokreml
# 161  https://www.facebook.com/TouristInformationCen...
# 162                  https://www.facebook.com/bflot.ru
# 168                                                NaN
# 172                                                NaN
# 173           https://www.facebook.com/specialcarefund
#
#                                             vk  \
# 4          https://vk.com/intellect.foundation
# 12            https://vk.com/pomoschsemie.luga
# 14                https://vk.com/securitymedia
# 18              https://vk.com/public173749519
# 22             https://vk.com/fonddobrovoblago
# 24             https://vk.com/mouc_krasnogorsk
# 29              https://vk.com/public194953135
# 32                https://vk.com/nkorazvitie64
# 33              https://vk.com/polzamarket_tmn
# 35                   https://vk.com/dobrubit72
# 37                       https://vk.com/nkonew
# 39                     https://vk.com/bf_ansar
# 40          https://vk.com/sovetdirectorovlenr
# 45                      https://vk.com/in.ural
# 48                https://vk.com/club194279021
# 55                   https://vk.com/dobropoint
# 61                    https://vk.com/teatrsela
# 63             https://vk.com/istoria1projecta
# 68                https://vk.com/club150109151
# 70                         https://www.vk.com/
# 72                https://vk.com/club199406803
# 75                        https://vk.com/mir48
# 78              https://vk.com/public208568512
# 79              https://oauth.vk.com/authorize
# 81                 https://vk.com/ano.avangard
# 84                             https://vk.com/
# 85                      http://vk.com/fc_pskov
# 87                https://vk.com/sandstormkids
# 94              https://vk.com/schoolalgorithm
# 95                 https://vk.com/kurultay_msk
# 96                https://vk.com/rivermakers18
# 98                https://vk.com/club190808798
# 103               https://vk.com/derevo.skazok
# 106                  https://vk.com/sadbonbons
# 120                   https://vk.com/timewebru
# 122                   https://vk.com/rugbyfili
# 123             https://vk.com/public198773760
# 124                 https://vk.com/id651167955
# 130                   https://vk.com/as_dosaaf
# 131                https://vk.com/ithubcollege
# 132                     https://vk.com/mipkpir
# 142                   https://vk.com/uipk21vek
# 146               https://vk.com/club201967965
# 154                  https://vk.com/kupnokreml
# 155                  https://vk.com/kupnokreml
# 161           https://vk.com/visit.kaliningrad
# 162             https://vk.com/public204471607
# 168                https://vk.com/ano_propotok
# 172  https://vk.me/https://vk.com/permspbvita/
# 173                      https://vk.com/rinden
#
#                                                     ig  \
# 4           https://instagram.com/intellect.foundation
# 12                                                 NaN
# 14                                                 NaN
# 18                                                 NaN
# 22     https://www.instagram.com/kirillpetrovhelp_sma/
# 24                                                 NaN
# 29                  https://www.instagram.com/nf_2217/
# 32           https://www.instagram.com/nko_razvitie64/
# 33           https://www.instagram.com/polzamarket.rf/
# 35                 https://www.instagram.com/dobrubit/
# 37                  https://www.instagram.com/nko_new/
# 39                 https://www.instagram.com/bf_ansar/
# 40                https://www.instagram.com/lendir161/
# 45                                                 NaN
# 48   https://instagram.com/rukapomoschi_ulan_ude?ig...
# 55                https://www.instagram.com/dobropoint
# 61                https://www.instagram.com/teatrsela/
# 63   https://instagram.com/istoria1projecta?igshid=...
# 68          https://www.instagram.com/arb_krasnoyarsk/
# 70                          https://www.instagram.com/
# 72               https://www.instagram.com/spartak.nko
# 75               https://www.instagram.com/art_omir48/
# 78               https://www.instagram.com/_family_bf/
# 79                                                 NaN
# 81                                                 NaN
# 84                          https://www.instagram.com/
# 85                       http://instagram.com/fcpskov/
# 87                                                 NaN
# 94          https://www.instagram.com/schoolalgorithm/
# 95                https://www.instagram.com/mayak_ano/
# 96                                                 NaN
# 98                                                 NaN
# 103           https://www.instagram.com/derevo.skazok/
# 106          https://www.instagram.com/bonbons_8marta/
# 120  https://www.instagram.com/accounts/login/?next...
# 122                  https://www.instagram.com/rcfili/
# 123  https://instagram.com/autsaidfond?igshid=yjjlf...
# 124             https://www.instagram.com/prirodada42/
# 130                https://www.instagram.com/uldosaaf/
# 131                                                NaN
# 132                  https://www.instagram.com/mipkpir
# 142               https://www.instagram.com/uipk21vek/
# 146                                                NaN
# 154              https://www.instagram.com/kupnokreml/
# 155              https://www.instagram.com/kupnokreml/
# 161       https://www.instagram.com/visit.kaliningrad/
# 162  https://www.instagram.com/bflot.ru/?igshid=11m...
# 168                                                NaN
# 172             https://www.instagram.com/vitapermspb/
# 173                                                NaN
#
#                                             ok  \
# 4                                          NaN
# 12                                         NaN
# 14                                         NaN
# 18                                         NaN
# 22                                         NaN
# 24                                         NaN
# 29                                         NaN
# 32                                         NaN
# 33                                         NaN
# 35          https://ok.ru/group/57613371506704
# 37          https://ok.ru/group/57814542844066
# 39                                         NaN
# 40                                         NaN
# 45                                         NaN
# 48                                         NaN
# 55                                         NaN
# 61          https://ok.ru/group/65264099786799
# 63                                         NaN
# 68                                         NaN
# 70                                         NaN
# 72                                         NaN
# 75          https://ok.ru/group/57275478180007
# 78                                         NaN
# 79                                         NaN
# 81         https://ok.ru/group/58691698163831/
# 84                                         NaN
# 85                                         NaN
# 87                                         NaN
# 94                                         NaN
# 95                                         NaN
# 96                                         NaN
# 98          https://ok.ru/group/58299107442917
# 103         https://ok.ru/group/60463412019326
# 106                                        NaN
# 120                                        NaN
# 122                                        NaN
# 123  https://ok.ru/group/58808097177725/topics
# 124         https://ok.ru/profile/578429914971
# 130                                        NaN
# 131                                        NaN
# 132                                        NaN
# 142                    https://ok.ru/uipk21vek
# 146                                        NaN
# 154                                        NaN
# 155                                        NaN
# 161                                        NaN
# 162                                        NaN
# 168           http://ano-propotok.ru/projects/
# 172                                        NaN
# 173         https://ok.ru/group/59278808055984
#
#                                                youtube  \
# 4                                                  NaN
# 12                                                 NaN
# 14                                                 NaN
# 18                                                 NaN
# 22   https://www.youtube.com/channel/UCiwOoMTRTDMa2...
# 24                                                 NaN
# 29   https://www.youtube.com/channel/UCp693gH6frXdB...
# 32                                                 NaN
# 33   https://www.youtube.com/channel/UChUFd04mbv3EA...
# 35                                                 NaN
# 37   https://www.youtube.com/channel/UCFT9z1cOqJgj8...
# 39   https://www.youtube.com/channel/UCcQGnryyEgXlS...
# 40                                                 NaN
# 45                                                 NaN
# 48                                                 NaN
# 55                                                 NaN
# 61   https://www.youtube.com/channel/UC5Z20PQT8i6VF...
# 63   https://www.youtube.com/channel/UCTOKrGEgMGM7e...
# 68                                                 NaN
# 70                                                 NaN
# 72                                                 NaN
# 75                                                 NaN
# 78   https://www.youtube.com/channel/UC5jfQlSpTuKXT...
# 79                                                 NaN
# 81                                                 NaN
# 84                                                 NaN
# 85                                                 NaN
# 87                                                 NaN
# 94   https://www.youtube.com/channel/UCpDPbcjVTDMCo...
# 95   https://www.youtube.com/channel/UCRGrC2OxalvZ2...
# 96   https://www.youtube.com/channel/UCTUKK2XaB6_vM...
# 98                                                 NaN
# 103                                                NaN
# 106                                                NaN
# 120  https://www.youtube.com/channel/UCTSnrzx_YKQOz...
# 122                                                NaN
# 123                                                NaN
# 124  https://www.youtube.com/channel/UC-2BOFCKxG2UF...
# 130                                                NaN
# 131  https://www.youtube.com/channel/UCL_A7Sva9qBoj...
# 132                                                NaN
# 142  https://www.youtube.com/channel/UCgsCjpf13de6n...
# 146                                                NaN
# 154                                                NaN
# 155                                                NaN
# 161  https://www.youtube.com/channel/UCtIgxXLNhEFll...
# 162                                                NaN
# 168                                                NaN
# 172  https://youtube.com/channel/UCXaJzwsxtOcVd-bpM...
# 173                                                NaN
#
#                                tiktok
# 4                                 NaN
# 12                                NaN
# 14                                NaN
# 18                                NaN
# 22                                NaN
# 24                                NaN
# 29                                NaN
# 32                                NaN
# 33                                NaN
# 35                                NaN
# 37                                NaN
# 39                                NaN
# 40                                NaN
# 45                                NaN
# 48                                NaN
# 55                                NaN
# 61                                NaN
# 63   https://vm.tiktok.com/ZSJnp19ep/
# 68                                NaN
# 70                                NaN
# 72                                NaN
# 75                                NaN
# 78                                NaN
# 79                                NaN
# 81                                NaN
# 84                                NaN
# 85                                NaN
# 87                                NaN
# 94                                NaN
# 95                                NaN
# 96                                NaN
# 98                                NaN
# 103                               NaN
# 106                               NaN
# 120                               NaN
# 122                               NaN
# 123                               NaN
# 124                               NaN
# 130                               NaN
# 131                               NaN
# 132                               NaN
# 142                               NaN
# 146                               NaN
# 154                               NaN
# 155                               NaN
# 161                               NaN
# 162                               NaN
# 168                               NaN
# 172                               NaN
# 173                               NaN

# %% [markdown]
# Some of the links weirdly send directly to vk.com, not to a specific group page. We clean those out:

# %%
ngos_with_vk = ngos_with_vk[~ngos_with_vk["vk"].str.endswith(".com/")]

# %%
ngos_with_vk.head(30)
# Out:
#                                     url  \
# 4        http://intellect-foundation.ru
# 12        http://рбоонадежда47регион.рф
# 14              http://securitymedia.ru
# 18          http://ecology-tatarstan.ru
# 22                    http://dvbfond.ru
# 24  http://адвокат-юрист-красногорск.рф
# 29                     http://nf2217.ru
# 32              http://nko-pazvitiye.ru
# 33                http://polzamarket.ru
# 35                  http://добрубыть.рф
# 37                   https://nko-new.ru
# 39                   http://bf-ansar.ru
# 40                     http://lendir.ru
# 45                    http://in-ural.ru
# 48              http://rukapomoshi03.ru
# 55                 http://dobropoint.ru
# 61                  http://teatrsela.ru
# 63           http://istoria1projecta.ru
# 68    http://дни-предпринимательства.рф
# 72                http://нко-спартак.рф
# 75                   http://art-omir.ru
# 78                   http://familybf.ru
# 79                   http://klubsila.ru
# 81               http://avangard-ano.ru
# 85                   http://fc-pskov.ru
# 87                  http://rkfavorit.ru
# 94           http://algorithm-school.ru
# 95                  http://oncomayak.ru
# 96                 http://rekigorodu.ru
# 98                  http://cleaninet.ru
#
#                                                    fb  \
# 4                                                 NaN
# 12                                                NaN
# 14     https://www.facebook.com/industriabezopasnosti
# 18                                                NaN
# 22                                                NaN
# 24                                                NaN
# 29  https://www.facebook.com/МРОО-помощи-пациентам...
# 32                                                NaN
# 33             https://www.facebook.com/u.bioproduct/
# 35                                                NaN
# 37            https://www.facebook.com/groups/nkonew/
# 39                                                NaN
# 40   https://www.facebook.com/groups/3207237442717865
# 45                                                NaN
# 48                                                NaN
# 55                                                NaN
# 61                 https://www.facebook.com/teatrsela
# 63                                                NaN
# 68                https://www.facebook.com/agpb24.ru/
# 72                                                NaN
# 75                                                NaN
# 78     https://www.facebook.com/Семья-103179345456877
# 79                                                NaN
# 81                                                NaN
# 85                                                NaN
# 87                                                NaN
# 94          https://www.facebook.com/schoolalgorithm/
# 95                                                NaN
# 96            https://www.facebook.com/rivermakers18/
# 98                                                NaN
#
#                                      vk  \
# 4   https://vk.com/intellect.foundation
# 12     https://vk.com/pomoschsemie.luga
# 14         https://vk.com/securitymedia
# 18       https://vk.com/public173749519
# 22      https://vk.com/fonddobrovoblago
# 24      https://vk.com/mouc_krasnogorsk
# 29       https://vk.com/public194953135
# 32         https://vk.com/nkorazvitie64
# 33       https://vk.com/polzamarket_tmn
# 35            https://vk.com/dobrubit72
# 37                https://vk.com/nkonew
# 39              https://vk.com/bf_ansar
# 40   https://vk.com/sovetdirectorovlenr
# 45               https://vk.com/in.ural
# 48         https://vk.com/club194279021
# 55            https://vk.com/dobropoint
# 61             https://vk.com/teatrsela
# 63      https://vk.com/istoria1projecta
# 68         https://vk.com/club150109151
# 72         https://vk.com/club199406803
# 75                 https://vk.com/mir48
# 78       https://vk.com/public208568512
# 79       https://oauth.vk.com/authorize
# 81          https://vk.com/ano.avangard
# 85               http://vk.com/fc_pskov
# 87         https://vk.com/sandstormkids
# 94       https://vk.com/schoolalgorithm
# 95          https://vk.com/kurultay_msk
# 96         https://vk.com/rivermakers18
# 98         https://vk.com/club190808798
#
#                                                    ig  \
# 4          https://instagram.com/intellect.foundation
# 12                                                NaN
# 14                                                NaN
# 18                                                NaN
# 22    https://www.instagram.com/kirillpetrovhelp_sma/
# 24                                                NaN
# 29                 https://www.instagram.com/nf_2217/
# 32          https://www.instagram.com/nko_razvitie64/
# 33          https://www.instagram.com/polzamarket.rf/
# 35                https://www.instagram.com/dobrubit/
# 37                 https://www.instagram.com/nko_new/
# 39                https://www.instagram.com/bf_ansar/
# 40               https://www.instagram.com/lendir161/
# 45                                                NaN
# 48  https://instagram.com/rukapomoschi_ulan_ude?ig...
# 55               https://www.instagram.com/dobropoint
# 61               https://www.instagram.com/teatrsela/
# 63  https://instagram.com/istoria1projecta?igshid=...
# 68         https://www.instagram.com/arb_krasnoyarsk/
# 72              https://www.instagram.com/spartak.nko
# 75              https://www.instagram.com/art_omir48/
# 78              https://www.instagram.com/_family_bf/
# 79                                                NaN
# 81                                                NaN
# 85                      http://instagram.com/fcpskov/
# 87                                                NaN
# 94         https://www.instagram.com/schoolalgorithm/
# 95               https://www.instagram.com/mayak_ano/
# 96                                                NaN
# 98                                                NaN
#
#                                      ok  \
# 4                                   NaN
# 12                                  NaN
# 14                                  NaN
# 18                                  NaN
# 22                                  NaN
# 24                                  NaN
# 29                                  NaN
# 32                                  NaN
# 33                                  NaN
# 35   https://ok.ru/group/57613371506704
# 37   https://ok.ru/group/57814542844066
# 39                                  NaN
# 40                                  NaN
# 45                                  NaN
# 48                                  NaN
# 55                                  NaN
# 61   https://ok.ru/group/65264099786799
# 63                                  NaN
# 68                                  NaN
# 72                                  NaN
# 75   https://ok.ru/group/57275478180007
# 78                                  NaN
# 79                                  NaN
# 81  https://ok.ru/group/58691698163831/
# 85                                  NaN
# 87                                  NaN
# 94                                  NaN
# 95                                  NaN
# 96                                  NaN
# 98   https://ok.ru/group/58299107442917
#
#                                               youtube  \
# 4                                                 NaN
# 12                                                NaN
# 14                                                NaN
# 18                                                NaN
# 22  https://www.youtube.com/channel/UCiwOoMTRTDMa2...
# 24                                                NaN
# 29  https://www.youtube.com/channel/UCp693gH6frXdB...
# 32                                                NaN
# 33  https://www.youtube.com/channel/UChUFd04mbv3EA...
# 35                                                NaN
# 37  https://www.youtube.com/channel/UCFT9z1cOqJgj8...
# 39  https://www.youtube.com/channel/UCcQGnryyEgXlS...
# 40                                                NaN
# 45                                                NaN
# 48                                                NaN
# 55                                                NaN
# 61  https://www.youtube.com/channel/UC5Z20PQT8i6VF...
# 63  https://www.youtube.com/channel/UCTOKrGEgMGM7e...
# 68                                                NaN
# 72                                                NaN
# 75                                                NaN
# 78  https://www.youtube.com/channel/UC5jfQlSpTuKXT...
# 79                                                NaN
# 81                                                NaN
# 85                                                NaN
# 87                                                NaN
# 94  https://www.youtube.com/channel/UCpDPbcjVTDMCo...
# 95  https://www.youtube.com/channel/UCRGrC2OxalvZ2...
# 96  https://www.youtube.com/channel/UCTUKK2XaB6_vM...
# 98                                                NaN
#
#                               tiktok
# 4                                NaN
# 12                               NaN
# 14                               NaN
# 18                               NaN
# 22                               NaN
# 24                               NaN
# 29                               NaN
# 32                               NaN
# 33                               NaN
# 35                               NaN
# 37                               NaN
# 39                               NaN
# 40                               NaN
# 45                               NaN
# 48                               NaN
# 55                               NaN
# 61                               NaN
# 63  https://vm.tiktok.com/ZSJnp19ep/
# 68                               NaN
# 72                               NaN
# 75                               NaN
# 78                               NaN
# 79                               NaN
# 81                               NaN
# 85                               NaN
# 87                               NaN
# 94                               NaN
# 95                               NaN
# 96                               NaN
# 98                               NaN

# %% [markdown]
# Some of the links start with "oauth.", but we need only vk domain:

# %%
ngos_with_vk = ngos_with_vk[ngos_with_vk["vk"].str.startswith("https://vk.com/")]

# %%
ngos_with_vk.head(30)
# Out:
#                                      url  \
# 4         http://intellect-foundation.ru
# 12         http://рбоонадежда47регион.рф
# 14               http://securitymedia.ru
# 18           http://ecology-tatarstan.ru
# 22                     http://dvbfond.ru
# 24   http://адвокат-юрист-красногорск.рф
# 29                      http://nf2217.ru
# 32               http://nko-pazvitiye.ru
# 33                 http://polzamarket.ru
# 35                   http://добрубыть.рф
# 37                    https://nko-new.ru
# 39                    http://bf-ansar.ru
# 40                      http://lendir.ru
# 45                     http://in-ural.ru
# 48               http://rukapomoshi03.ru
# 55                  http://dobropoint.ru
# 61                   http://teatrsela.ru
# 63            http://istoria1projecta.ru
# 68     http://дни-предпринимательства.рф
# 72                 http://нко-спартак.рф
# 75                    http://art-omir.ru
# 78                    http://familybf.ru
# 81                http://avangard-ano.ru
# 87                   http://rkfavorit.ru
# 94            http://algorithm-school.ru
# 95                   http://oncomayak.ru
# 96                  http://rekigorodu.ru
# 98                   http://cleaninet.ru
# 103              http://дерево-сказок.рф
# 106                   http://bon-bons.ru
#
#                                                     fb  \
# 4                                                  NaN
# 12                                                 NaN
# 14      https://www.facebook.com/industriabezopasnosti
# 18                                                 NaN
# 22                                                 NaN
# 24                                                 NaN
# 29   https://www.facebook.com/МРОО-помощи-пациентам...
# 32                                                 NaN
# 33              https://www.facebook.com/u.bioproduct/
# 35                                                 NaN
# 37             https://www.facebook.com/groups/nkonew/
# 39                                                 NaN
# 40    https://www.facebook.com/groups/3207237442717865
# 45                                                 NaN
# 48                                                 NaN
# 55                                                 NaN
# 61                  https://www.facebook.com/teatrsela
# 63                                                 NaN
# 68                 https://www.facebook.com/agpb24.ru/
# 72                                                 NaN
# 75                                                 NaN
# 78      https://www.facebook.com/Семья-103179345456877
# 81                                                 NaN
# 87                                                 NaN
# 94           https://www.facebook.com/schoolalgorithm/
# 95                                                 NaN
# 96             https://www.facebook.com/rivermakers18/
# 98                                                 NaN
# 103                                                NaN
# 106             https://www.facebook.com/bonbons8marta
#
#                                       vk  \
# 4    https://vk.com/intellect.foundation
# 12      https://vk.com/pomoschsemie.luga
# 14          https://vk.com/securitymedia
# 18        https://vk.com/public173749519
# 22       https://vk.com/fonddobrovoblago
# 24       https://vk.com/mouc_krasnogorsk
# 29        https://vk.com/public194953135
# 32          https://vk.com/nkorazvitie64
# 33        https://vk.com/polzamarket_tmn
# 35             https://vk.com/dobrubit72
# 37                 https://vk.com/nkonew
# 39               https://vk.com/bf_ansar
# 40    https://vk.com/sovetdirectorovlenr
# 45                https://vk.com/in.ural
# 48          https://vk.com/club194279021
# 55             https://vk.com/dobropoint
# 61              https://vk.com/teatrsela
# 63       https://vk.com/istoria1projecta
# 68          https://vk.com/club150109151
# 72          https://vk.com/club199406803
# 75                  https://vk.com/mir48
# 78        https://vk.com/public208568512
# 81           https://vk.com/ano.avangard
# 87          https://vk.com/sandstormkids
# 94        https://vk.com/schoolalgorithm
# 95           https://vk.com/kurultay_msk
# 96          https://vk.com/rivermakers18
# 98          https://vk.com/club190808798
# 103         https://vk.com/derevo.skazok
# 106            https://vk.com/sadbonbons
#
#                                                     ig  \
# 4           https://instagram.com/intellect.foundation
# 12                                                 NaN
# 14                                                 NaN
# 18                                                 NaN
# 22     https://www.instagram.com/kirillpetrovhelp_sma/
# 24                                                 NaN
# 29                  https://www.instagram.com/nf_2217/
# 32           https://www.instagram.com/nko_razvitie64/
# 33           https://www.instagram.com/polzamarket.rf/
# 35                 https://www.instagram.com/dobrubit/
# 37                  https://www.instagram.com/nko_new/
# 39                 https://www.instagram.com/bf_ansar/
# 40                https://www.instagram.com/lendir161/
# 45                                                 NaN
# 48   https://instagram.com/rukapomoschi_ulan_ude?ig...
# 55                https://www.instagram.com/dobropoint
# 61                https://www.instagram.com/teatrsela/
# 63   https://instagram.com/istoria1projecta?igshid=...
# 68          https://www.instagram.com/arb_krasnoyarsk/
# 72               https://www.instagram.com/spartak.nko
# 75               https://www.instagram.com/art_omir48/
# 78               https://www.instagram.com/_family_bf/
# 81                                                 NaN
# 87                                                 NaN
# 94          https://www.instagram.com/schoolalgorithm/
# 95                https://www.instagram.com/mayak_ano/
# 96                                                 NaN
# 98                                                 NaN
# 103           https://www.instagram.com/derevo.skazok/
# 106          https://www.instagram.com/bonbons_8marta/
#
#                                       ok  \
# 4                                    NaN
# 12                                   NaN
# 14                                   NaN
# 18                                   NaN
# 22                                   NaN
# 24                                   NaN
# 29                                   NaN
# 32                                   NaN
# 33                                   NaN
# 35    https://ok.ru/group/57613371506704
# 37    https://ok.ru/group/57814542844066
# 39                                   NaN
# 40                                   NaN
# 45                                   NaN
# 48                                   NaN
# 55                                   NaN
# 61    https://ok.ru/group/65264099786799
# 63                                   NaN
# 68                                   NaN
# 72                                   NaN
# 75    https://ok.ru/group/57275478180007
# 78                                   NaN
# 81   https://ok.ru/group/58691698163831/
# 87                                   NaN
# 94                                   NaN
# 95                                   NaN
# 96                                   NaN
# 98    https://ok.ru/group/58299107442917
# 103   https://ok.ru/group/60463412019326
# 106                                  NaN
#
#                                                youtube  \
# 4                                                  NaN
# 12                                                 NaN
# 14                                                 NaN
# 18                                                 NaN
# 22   https://www.youtube.com/channel/UCiwOoMTRTDMa2...
# 24                                                 NaN
# 29   https://www.youtube.com/channel/UCp693gH6frXdB...
# 32                                                 NaN
# 33   https://www.youtube.com/channel/UChUFd04mbv3EA...
# 35                                                 NaN
# 37   https://www.youtube.com/channel/UCFT9z1cOqJgj8...
# 39   https://www.youtube.com/channel/UCcQGnryyEgXlS...
# 40                                                 NaN
# 45                                                 NaN
# 48                                                 NaN
# 55                                                 NaN
# 61   https://www.youtube.com/channel/UC5Z20PQT8i6VF...
# 63   https://www.youtube.com/channel/UCTOKrGEgMGM7e...
# 68                                                 NaN
# 72                                                 NaN
# 75                                                 NaN
# 78   https://www.youtube.com/channel/UC5jfQlSpTuKXT...
# 81                                                 NaN
# 87                                                 NaN
# 94   https://www.youtube.com/channel/UCpDPbcjVTDMCo...
# 95   https://www.youtube.com/channel/UCRGrC2OxalvZ2...
# 96   https://www.youtube.com/channel/UCTUKK2XaB6_vM...
# 98                                                 NaN
# 103                                                NaN
# 106                                                NaN
#
#                                tiktok
# 4                                 NaN
# 12                                NaN
# 14                                NaN
# 18                                NaN
# 22                                NaN
# 24                                NaN
# 29                                NaN
# 32                                NaN
# 33                                NaN
# 35                                NaN
# 37                                NaN
# 39                                NaN
# 40                                NaN
# 45                                NaN
# 48                                NaN
# 55                                NaN
# 61                                NaN
# 63   https://vm.tiktok.com/ZSJnp19ep/
# 68                                NaN
# 72                                NaN
# 75                                NaN
# 78                                NaN
# 81                                NaN
# 87                                NaN
# 94                                NaN
# 95                                NaN
# 96                                NaN
# 98                                NaN
# 103                               NaN
# 106                               NaN

# %% [markdown]
# Work with "shape.php" kind of links:

# %%
ngos_with_vk = ngos_with_vk[~ngos_with_vk["vk"].str.startswith("https://vk.com/share.php")]

# %%
ngos_with_vk.shape[0]
# Out:
# 3765

# %% [markdown]
# Save file

# %%
ngos_with_vk.to_csv("../data/2021_dec_social_networks_vk_clean.csv", encoding="utf-8")

# %%
# For next runs
# ngos_with_vk = pd.read_csv("../data/2021_dec_social_networks_vk_clean.csv", encoding="utf-8")
# ngos_with_vk.head()

# %%
ngo_vks = ngo_vks[~ngo_vks["vk"].isnull()]

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: re.search(r'(.+)\?', x).group(1) if "?" in x else x)

# %%
ngo_vks = ngo_vks[~ngo_vks["vk"].str.endswith(".com/")]

# %%
ngo_vks = ngo_vks[ngo_vks["vk"].str.startswith("https://vk.com/")]

# %%
ngo_vks = ngo_vks[~ngo_vks["vk"].str.startswith("https://vk.com/share.php")]

# %%
ngo_vks.shape[0]
# Out:
# 3871

# %% [markdown]
# In the end vk_links.csv has more valid links although it is shorter. So I'm going to use this dataset. Let us save it:

# %%
ngo_vks.to_csv("../data/2021_dec_social_networks_vk_clean.csv", encoding="utf-8")

# %%
ngo_vks = pd.read_csv("../data/2021_dec_social_networks_vk_clean.csv", encoding="utf-8")
ngo_vks.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1                               vk
# 0           0           633            https://vk.com/ratris
# 1           1           634  https://vk.com//public203415983
# 2           2           635  https://vk.com//public203659500
# 3           3           636    https://vk.com/15days_victory
# 4           4           637        https://vk.com/18blagodar

# %% [markdown]
# More problematic link types:
#
# - https://vk.com/wall-79408209 link to all posts on the wall of the public -> https://vk.com/public79408209
# - https://vk.com/wall-111030342_8435  link to a specific post on the wall of a public -> https://vk.com/public111030342
# - https://vk.com/topic-88758316_31319416  link to a topic in a public we are interested in -> https://vk.com/public88758316
# - https://vk.com/@ratris  it is a site page not a main vk public page -> https://vk.com/ratris
# - https://vk.com/prodlenkaplushttps://vk.com/prodlenkaplus  simple mistake -> https://vk.com/prodlenkaplus
# - some of the links have `/` on the end -> strip
# - https://vk.com/album-104692916_282960157 link to an album -> https://vk.com/public104692916

# %%
link = "https://vk.com/wall-79408209"

if re.match(r'.*?/wall-\d+$', link):
    print(link.replace('wall-', 'public'))
# Out:
# https://vk.com/public79408209

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.replace('wall-', 'public') if re.match(r'.*?/wall-\d+$', x) else x)

# %%
link = "https://vk.com/wall-111030342_435"

if re.match(r'.*?/wall-\d+?_\d+$', link):
    link = link.split('_')[0]
    print(link.replace('wall-', 'public'))
# Out:
# https://vk.com/public111030342

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.split('_')[0].replace('wall-', 'public') if re.match(r'.*?/wall-\d+?_\d+$', x) else x)

# %%
link = "https://vk.com/topic-88758316_31319416"

if re.match(r'.*?/topic-\d+?_\d+$', link):
    link = link.split('_')[0]
    print(link.replace('topic-', 'public'))
# Out:
# https://vk.com/public88758316

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.split('_')[0].replace('wall-', 'public') if re.match(r'.*?/wall-\d+?_\d+$', x) else x)

# %%
link = "https://vk.com/album-104692916_282960157"

if re.match(r'.*?/album-\d+?_\d+$', link):
    link = link.split('_')[0]
    print(link.replace('album-', 'public'))
# Out:
# https://vk.com/public104692916

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.split('_')[0].replace('album-', 'public') if re.match(r'.*?/album-\d+?_\d+$', x) else x)

# %%
link = "https://vk.com/albums-149498770"

if re.match(r'.*?/albums-\d+$', link):
    print(link.replace('albums-', 'public'))
# Out:
# https://vk.com/public149498770

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.replace('albums-', 'public') if re.match(r'.*?/albums-\d+$', x) else x)

# %%
link = "https://vk.com/@ratris"

if "/@" in link:
    print(link.replace('@', ''))
# Out:
# https://vk.com/ratris

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.replace('@', '') if "/@" in x else x)

# %%
link = "https://vk.com/prodlenkaplushttps://vk.com/prodlenkaplus"
dubles_test = link.split('https://')
if len(dubles_test) > 2:
    print("https://" + dubles_test[1])
# Out:
# https://vk.com/prodlenkaplus

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: "https://" + x.split('https://')[1] if len(x.split('https://')) > 2 else x)

# %%
link = "https://vk.com/album220163822_240663742"

if re.match(r'.*?/album\d+?_\d+$', link):
    link = link.split('_')[0]
    print(link.replace('album', 'public'))
# Out:
# https://vk.com/public220163822

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.split('_')[0].replace('album', 'public') if re.match(r'.*?/album\d+?_\d+$', x) else x)

# %%
link = "https://vk.com/app5619682_-37666750#502331"

if re.match(r'.*?/app\d+?_-\d+?#\d+$', link):
    m = re.search(r'-(\d+?)#', link)
    print("https://vk.com/public" + m.group(1))
# Out:
# https://vk.com/public37666750

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: "https://vk.com/public" + re.search(r'-(\d+?)#', x).group(1) if re.match(r'.*?/app\d+?_-\d+?#\d+$', x) else x)

# %%
link = "https://vk.com/app5708398_-142199366"

if re.match(r'.*?/app\d+?_-\d+$', link):
    m = re.search(r'-(\d+)', link)
    print("https://vk.com/public" + m.group(1))
# Out:
# https://vk.com/public142199366

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: "https://vk.com/public" + re.search(r'-(\d+)', x).group(1) if re.match(r'.*?/app\d+?_-\d+$', x) else x)

# %%
link = "https://vk.com/doc-134882220_448563071"

if re.match(r'.*?/doc-\d+?_\d+$', link):
    link = link.split('_')[0]
    print(link.replace('doc-', 'public'))
# Out:
# https://vk.com/public134882220

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.split('_')[0].replace('doc-', 'public') if re.match(r'.*?/doc-\d+?_\d+$', x) else x)

# %%
link = "https://vk.com/doc345920167_631326625" # this link is just broken

if re.match(r'.*?/doc\d+?_\d+$', link):
    link = link.split('_')[0]
    print(link.replace('doc', 'public'))
# Out:
# https://vk.com/public345920167

# %%
ngo_vks.drop(ngo_vks[ngo_vks["vk"] == "https://vk.com/doc345920167_631326625"].index, inplace=True)

# %%
ngo_vks.drop(ngo_vks[ngo_vks["vk"] == "https://vk.com/im"].index, inplace=True)

# %%
link = "https://vk.com/docs-125680016"

if re.match(r'.*?/docs-\d+$', link):
    print(link.replace('docs-', 'public'))
# Out:
# https://vk.com/public125680016

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.replace('docs-', 'public') if re.match(r'.*?/docs-\d+$', x) else x)

# %%
ngo_vks.drop(ngo_vks[ngo_vks["vk"] == "https://vk.com/images/blank.gif"].index, inplace=True)

# %%
link = "https://vk.com/podcast-3424373_456240564"

if re.match(r'.*?/podcast-\d+?_\d+$', link):
    link = link.split('_')[0]
    print(link.replace('podcast-', 'public'))
# Out:
# https://vk.com/public3424373

# %%
ngo_vks["vk"] = ngo_vks["vk"].apply(lambda x: x.split('_')[0].replace('podcast-', 'public') if re.match(r'.*?/podcast-\d+?_\d+$', x) else x)

# %%
ngo_vks.to_csv("../data/2021_dec_social_networks_vk_clean.csv", encoding="utf-8")

# %%
# on the next run just read
ngo_vks = pd.read_csv("../data/2021_dec_social_networks_vk_clean.csv", encoding="utf-8")

# %% [markdown]
# ## Test loop

# %%
ngo_vks.shape[0]
# Out:
# 3864

# %%
def get_count(method, group_id):
    #print(group_id, " ", entry.vk)
    if 'public' in group_id:
        group_num = re.sub('public', '', group_id)
        vk_request = "https://api.vk.com/method/" + method + group_num + "&v=5.131&access_token="
    else:
        vk_request = "https://api.vk.com/method/" + method + group_id + "&v=5.131&access_token="
    # "error_msg":"Access denied: group hide members"
    # "error_msg":"Invalid group id"
    response = json.loads(send_request(vk_request))
    return response


def get_posts_per_month(response_wall):
    if "response" in response_wall:
        months = defaultdict(list)
        for item in response_wall["response"]["items"]:
            timestamp = item["date"]
            dt_object = datetime.fromtimestamp(timestamp)
            year = dt_object.strftime("%Y")
            month = dt_object.strftime("%m")
            months[str(year) + str(month)].append(item["id"])
        if len(months) > 0:
            posts_per_month = sum([len(val) for val in months.values()]) / len(months)
            return round(posts_per_month, 2)
        else:
            return None
    else:
        return None


def get_count_and_mean(response_wall: dict, feature: str) -> tuple:
    if "response" in response_wall:
        counts = []
        for item in response_wall["response"]["items"]:
            if feature not in item:
                return None, None
            count = item[feature]["count"]
            counts.append(count)
        if len(counts) > 0:
            mean_val = sum(counts) / len(counts)
            return sum(counts), round(mean_val, 2)
        else:
            return None, None
    else:
        return None, None
    
    
def get_binary_param(response_wall: dict, feature: str) -> tuple:
    if "response" in response_wall:
        ads = []
        for item in response_wall["response"]["items"]:
            if feature not in item:
                return None, None
            ad_or_not = item[feature]
            ads.append(ad_or_not)
        if len(ads) > 0:
            mean_val = sum(ads) / len(ads)
            return sum(ads), round(mean_val, 2)
        else:
            return None, None
    else:
        return None, None

# %%
a = list("abc")
a[1:2]
# Out:
# ['b']

# %%
from time import sleep
from random import randint
import json
from datetime import datetime
from collections import defaultdict


count_members = []
count_posts_all = []
count_posts_per_month = []
likes_overall_all, likes_mean_all = [], []
comments_overall_all, comments_mean_all = [], []
reposts_overall_all, reposts_mean_all = [], []
views_overall_all, views_mean_all = [], []
ads_overall_all, ads_mean_all = [], []

for entry in ngo_vks.iloc[3000:4000].itertuples():
    group_id = re.sub('https://vk.com/', '', entry.vk).strip('/')
    
    # get members count
    members_method = "groups.getMembers?group_id="
    response = get_count(members_method, group_id)
    if "response" in response:
        count_members.append(response["response"]["count"])
    else:
        count_members.append(None)
    
    # get posts overall count
    posts_method = "wall.get?domain="
    response_wall = get_count(posts_method, group_id)
    if "response" in response_wall:
        count_posts_all.append(response_wall["response"]["count"])
    else:
        count_posts_all.append(None)
    
    # get posts per month
    posts_per_month = get_posts_per_month(response_wall)
    count_posts_per_month.append(posts_per_month)
    
    # get likes overall count & get mean likes per post
    likes_overall, likes_mean = get_count_and_mean(response_wall, "likes")
    # get comments overall count & get comments per post
    comments_overall, comments_mean = get_count_and_mean(response_wall, "comments")
    # get reposts overall count & get reposts per post
    reposts_overall, reposts_mean = get_count_and_mean(response_wall, "likes")
    # get views overall count & get views per post
    views_overall, views_mean = get_count_and_mean(response_wall, "views")
    
    # 'marked_as_ads' binary parameter. Also important to my mind
    ads_overall, ads_mean = get_binary_param(response_wall, "marked_as_ads")
    
    # append all parameters that are left to make a df column
    likes_overall_all.append(likes_overall)
    likes_mean_all.append(likes_mean)
    comments_overall_all.append(comments_overall)
    comments_mean_all.append(comments_mean)
    reposts_overall_all.append(reposts_overall)
    reposts_mean_all.append(reposts_mean)
    views_overall_all.append(views_overall)
    views_mean_all.append(views_mean)
    ads_overall_all.append(ads_overall)
    ads_mean_all.append(ads_mean)
    
    sleep(randint(0,2))

# %%
len(count_members)
# Out:
# 864

# %%
# test
print(len(views_overall_all), len(count_posts_all), len(likes_overall_all), len(likes_mean_all), len(comments_overall_all), len(comments_mean_all), len(reposts_overall_all), len(reposts_mean_all))
# Out:
# 864 864 864 864 864 864 864 864

# %%
# create columns
# first run

ngo_vks["count_members"] = count_members + [None] * (len(ngo_vks)-393-1)  # !!!! uneven
ngo_vks["count_posts_all"] = count_posts_all + [None] * (len(ngo_vks)-393)
ngo_vks["count_posts_per_month"] = count_posts_per_month + [None] * (len(ngo_vks)-393)
ngo_vks["likes_overall_all"] = likes_overall_all + [None] * (len(ngo_vks)-393)
ngo_vks["likes_mean_all"] = likes_mean_all + [None] * (len(ngo_vks)-393)
ngo_vks["comments_overall_all"] = comments_overall_all + [None] * (len(ngo_vks)-393)
ngo_vks["comments_mean_all"] = comments_mean_all + [None] * (len(ngo_vks)-393)
ngo_vks["reposts_overall_all"] = reposts_overall_all + [None] * (len(ngo_vks)-393)
ngo_vks["reposts_mean_all"] = reposts_mean_all + [None] * (len(ngo_vks)-393)
ngo_vks["views_overall_all"] = views_overall_all + [None] * (len(ngo_vks)-393)
ngo_vks["views_mean_all"] = views_mean_all + [None] * (len(ngo_vks)-393)
ngo_vks["ads_overall_all"] = ads_overall_all + [None] * (len(ngo_vks)-393)
ngo_vks["ads_mean_all"] = ads_mean_all + [None] * (len(ngo_vks)-393)

# %%
# next runs are in batches
k = 3000  # сдвиг
for i in range(3000, 3864):
    ngo_vks.at[i, "count_members"] = count_members[i-k]
    ngo_vks.at[i, "count_posts_all"] = count_posts_all[i-k]
    ngo_vks.at[i, "count_posts_per_month"] = count_posts_per_month[i-k]
    ngo_vks.at[i, "likes_overall_all"] = likes_overall_all[i-k]
    ngo_vks.at[i, "likes_mean_all"] = likes_mean_all[i-k]
    ngo_vks.at[i, "comments_overall_all"] = comments_overall_all[i-k]
    ngo_vks.at[i, "comments_mean_all"] = comments_mean_all[i-k]
    ngo_vks.at[i, "reposts_overall_all"] = reposts_overall_all[i-k]
    ngo_vks.at[i, "reposts_mean_all"] = reposts_mean_all[i-k]
    ngo_vks.at[i, "views_overall_all"] = views_overall_all[i-k]
    ngo_vks.at[i, "views_mean_all"] = views_mean_all[i-k]
    ngo_vks.at[i, "ads_overall_all"] = ads_overall_all[i-k]
    ngo_vks.at[i, "ads_mean_all"] = ads_mean_all[i-k]

# %%
ngo_vks.iloc[3861:3880]
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 3861        3861          3868            3868              4501
# 3862        3862          3869            3869              4502
# 3863        3863          3870            3870              4503
#
#                               vk  count_members  count_posts_all  \
# 3861        https://vk.com/zrp56          294.0            574.0
# 3862      https://vk.com/zukk174            NaN          15882.0
# 3863  https://vk.com/zvezda_2005         6965.0           6187.0
#
#       count_posts_per_month  likes_overall_all  likes_mean_all  \
# 3861                   20.0                0.0            0.00
# 3862                   10.0              912.0           45.60
# 3863                   10.0             2159.0          107.95
#
#       comments_overall_all  comments_mean_all  reposts_overall_all  \
# 3861                   0.0               0.00                  0.0
# 3862                  35.0               1.75                912.0
# 3863                 150.0               7.50               2159.0
#
#       reposts_mean_all  views_overall_all  views_mean_all  ads_overall_all  \
# 3861              0.00              178.0             8.9              0.0
# 3862             45.60            86178.0          4308.9              0.0
# 3863            107.95            55144.0          2757.2              0.0
#
#       ads_mean_all
# 3861           0.0
# 3862           0.0
# 3863           0.0

# %%
ngo_vks.tail()
# Out:
#       Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 3859        3859          3866            3866              4499
# 3860        3860          3867            3867              4500
# 3861        3861          3868            3868              4501
# 3862        3862          3869            3869              4502
# 3863        3863          3870            3870              4503
#
#                                vk  count_members  count_posts_all  \
# 3859    https://vk.com/zoolimpopo        45227.0           2271.0
# 3860  https://vk.com/zpokolenie33          540.0           1857.0
# 3861         https://vk.com/zrp56          294.0            574.0
# 3862       https://vk.com/zukk174            NaN          15882.0
# 3863   https://vk.com/zvezda_2005         6965.0           6187.0
#
#       count_posts_per_month  likes_overall_all  likes_mean_all  \
# 3859                   10.0             7245.0          362.25
# 3860                   10.0              256.0           12.80
# 3861                   20.0                0.0            0.00
# 3862                   10.0              912.0           45.60
# 3863                   10.0             2159.0          107.95
#
#       comments_overall_all  comments_mean_all  reposts_overall_all  \
# 3859                 232.0              11.60               7245.0
# 3860                   1.0               0.05                256.0
# 3861                   0.0               0.00                  0.0
# 3862                  35.0               1.75                912.0
# 3863                 150.0               7.50               2159.0
#
#       reposts_mean_all  views_overall_all  views_mean_all  ads_overall_all  \
# 3859            362.25           459325.0        22966.25              0.0
# 3860             12.80             6890.0          344.50              0.0
# 3861              0.00              178.0            8.90              0.0
# 3862             45.60            86178.0         4308.90              0.0
# 3863            107.95            55144.0         2757.20              0.0
#
#       ads_mean_all
# 3859           0.0
# 3860           0.0
# 3861           0.0
# 3862           0.0
# 3863           0.0

# %%
# save data
ngo_vks.to_csv("../data/2021_dec_vk_parsed.csv", encoding="utf-8")

# %%
# read data to fill it up
ngo_vks = pd.read_csv("../data/2021_dec_vk_parsed.csv", encoding="utf-8")

# %% [markdown]
# ## Short analytics

# %%
ngo_vks = ngo_vks.drop(ngo_vks.columns[[0,1,2,3]], axis=1)

# %%
ngo_vks.head()
# Out:
#                                 vk  count_members  count_posts_all  \
# 0            https://vk.com/ratris         3985.0           1707.0
# 1  https://vk.com//public203415983            5.0             18.0
# 2  https://vk.com//public203659500           54.0             18.0
# 3    https://vk.com/15days_victory          146.0            106.0
# 4        https://vk.com/18blagodar          751.0            807.0
#
#    count_posts_per_month  likes_overall_all  likes_mean_all  \
# 0                   6.67              230.0           11.50
# 1                   1.29              458.0           25.44
# 2                   1.29              458.0           25.44
# 3                   2.50                4.0            0.20
# 4                   4.00              532.0           26.60
#
#    comments_overall_all  comments_mean_all  reposts_overall_all  \
# 0                  14.0               0.70                230.0
# 1                  13.0               0.72                458.0
# 2                  13.0               0.72                458.0
# 3                   0.0               0.00                  4.0
# 4                  23.0               1.15                532.0
#
#    reposts_mean_all  views_overall_all  views_mean_all  ads_overall_all  \
# 0             11.50             7150.0           357.5              0.0
# 1             25.44                NaN             NaN              NaN
# 2             25.44                NaN             NaN              NaN
# 3              0.20                NaN             NaN              0.0
# 4             26.60            23910.0          1195.5              0.0
#
#    ads_mean_all         group_id
# 0           0.0           ratris
# 1           NaN  public203415983
# 2           NaN  public203659500
# 3           0.0   15days_victory
# 4           0.0       18blagodar

# %%
# add group_id column to make graphs prettier
group_names = []
for entry in ngo_vks.itertuples():
    group_id = re.sub('https://vk.com/', '', entry.vk).strip('/')
    group_names.append(group_id)

# %%
ngo_vks["group_id"] = group_names

# %%
import plotly.express as px


fig = px.bar(ngo_vks[ngo_vks["count_members"] > 130000], x="group_id", y="count_members", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="cef5684a-97e8-424b-a80c-77366d478087" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cef5684a-97e8-424b-a80c-77366d478087")) {
#                     Plotly.newPlot(
#                         'cef5684a-97e8-424b-a80c-77366d478087',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>count_members=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["alexander.kovtunets", "applevk", "aviasalesru", "cultrf", "donorsearch", "er_ru", "faktu_taina", "fhr", "foma_magazine", "khl", "olympic_russia", "pravmir", "public30698831", "rostelecom", "spastv", "svo196", "teamrussia", "vpravoslav", "vsezapobedu", "wrestrus_ru", "yousuperntv"], "xaxis": "x", "y": [194273.0, 144850.0, 304950.0, 427128.0, 202402.0, 137420.0, 2919332.0, 394520.0, 148447.0, 1752401.0, 170096.0, 150648.0, 184641.0, 679196.0, 176881.0, 193008.0, 462925.0, 276009.0, 134676.0, 234259.0, 139440.0], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig = px.bar(ngo_vks[ngo_vks["count_posts_all"] > 40000], x="group_id", y="count_posts_all", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="cdc8c6f5-24be-4056-a541-68c0052b54c9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cdc8c6f5-24be-4056-a541-68c0052b54c9")) {
#                     Plotly.newPlot(
#                         'cdc8c6f5-24be-4056-a541-68c0052b54c9',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>count_posts_all=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["aif.karelia", "animals_pk", "bandyvesti", "dan_kazan", "evpa_petsfond", "faktu_taina", "karelinformru", "mayaksbor", "otrussia", "poteriashki", "poteryashka_perm", "pravmir", "ptzgovorit", "radio_adam", "svpressa", "verniydrug", "zoo_up"], "xaxis": "x", "y": [40644.0, 56725.0, 52035.0, 54040.0, 49095.0, 43761.0, 156996.0, 59547.0, 60109.0, 130248.0, 325799.0, 89252.0, 226687.0, 70999.0, 105064.0, 254785.0, 64361.0], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig = px.bar(ngo_vks[ngo_vks["count_posts_per_month"] > 1], x="group_id", y="count_posts_per_month", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="eed8099c-70a8-4006-92ce-976208a8bea9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("eed8099c-70a8-4006-92ce-976208a8bea9")) {
#                     Plotly.newPlot(
#                         'eed8099c-70a8-4006-92ce-976208a8bea9',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>count_posts_per_month=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["ratris", "public203415983", "public203659500", "15days_victory", "18blagodar", "1fondnfr", "1mestopodsolncem", "1tvcrimea", "1vosgmpr", "29lime", "2polza", "2sigma", "35voi", "36rck", "39kovcheg", "3v_sykt", "4istaya_vuoksa", "5sov_ru", "66judo", "74dosaaf", "75opora", "a_sro_kiruip", "aamosru", "abadvantage", "abelman2016", "abicufa", "above_rainbow_samara", "absolutnn", "aca_profkom", "academdpo", "academpark_nsk", "academy_balabanovo", "academy_igorkrutoy", "academy_mubint", "academy_raan", "academy.teamline", "academydynamo", "academykonopleva", "academyviner_group", "academyvoice", "acgi_id", "action.crimea", "action29ru", "actual_comment", "ada_ugra", "administraciya_anadyrya", "adresa_miloserdiya", "advitafund", "advocateoffice", "aernch", "aerobic73", "aerobicgymnasticsperm59", "aerobicnv", "aerobicrussia", "aerobics_kzn", "aerospaceschool.usatu", "af_association", "afunrf", "ahln2020", "aidrussia", "aif.dobroeserdce", "aif.karelia", "aikido_tatarstan", "aimfond_ru", "airathleticsrus", "airclub12", "airpofficial", "airschoolru", "aismoscow", "aivexpert", "akademiyasamara", "akimoscow", "akit_rf", "akmns", "akozij111", "akrobatika71", "aksyukru", "aktivvolna", "albacademy", "albertina39", "albion_89", "public104692916", "public138646553", "public153805392", "public200298785", "public204266518", "public204266518", "public21985", "public41317998", "public77458679", "public77458679", "public91957578", "public96803541", "public220163822", "public149498770", "public158659266", "public46773574", "public46899491", "public48544560", "public84971799", "albusss", "aldan_mini_football", "aleksmedrzd", "aleshafond", "alex_klim", "alexander.kovtunets", "alh2017", "alice050495", "alisafond", "alleyasportslava", "alliance4animals", "almetweb", "alparicharity", "alrf.region69", "alrf73", "alrfkuban", "alta.soft", "altaidetfond22ru", "altayrgo", "altfond22", "altigz", "alumnispbu", "ambdoc", "amcult", "amfr_official", "amma_kirov", "amolodost", "amtec_fund", "amtur28", "amur_kprf", "amwayforfuture", "andjievskogo", "andreevskayaschool", "andreydegtyrev", "angelautoclub", "angiolsurgery", "animals_pk", "ano_bcpv", "ano_dpo", "ano_ecology_orel", "ano_nest_m", "ano_omega", "ano_propotok", "ano_riot", "ano_universum", "ano_verba", "ano_vostokzapad", "ano.avangard", "ano.csp.nadegda", "ano.zabota.sosnogorsk", "anoarvt", "anocentrdetstva", "anocnp", "anocspnadezhda", "anocspp16", "anodkb", "anodocpp", "anodpo.csfps", "anodposnta", "anoiiraedu", "anoiks", "anoiniciativa", "anoinirsaratov", "anoisopm", "anokontrast", "anolotos", "anomamulya", "anomirdetstva", "anomizb", "anomy_ru", "anonoviyvzgliyd", "anoorientir", "anopomokit", "anoroadtolife", "anorose", "anoroskosmos", "anosoglasie", "anosoldom", "anosovet", "anosudexpert", "anotae", "anovn", "anoyakhont", "antinarko36", "antiworkshop", "aoikur", "aotko", "aoz_nmk", "apartment.talks", "apbdeozal", "public37666750", "public37666750", "public142199366", "public112445420", "public64876531", "apparel39", "applevk", "apsheronufa", "aptonline", "arabesk_msk", "arbicon_ru", "arch.conservation", "archaeology.perm", "archfest", "arctic_on", "arcticmedicaltraining", "arcticpeople89", "ardi_svet", "ardip_mo", "area59ru", "arenasporta33", "argonweldingperm", "arh_eparhia", "arhiereiskaya_dacha", "arhkarate", "arhredcross", "ariadnatour18", "arifmetika_dobra", "ariy31", "arm_cerkov", "armizon_72", "arspress", "art_assamblei", "art_details", "artbene", "artdesign59", "artistunionru", "artlexufa", "artperedvizhenie", "artplaybunker", "artro61", "artsch2", "artscienceandsport", "artvorota", "as_detiplus", "as_dosaaf", "asi_ru", "asintegracia", "asmu.official", "asnova1005", "aso18_ru", "asppodrostok", "assistance ...

# %%
fig = px.bar(ngo_vks[ngo_vks["likes_overall_all"] > 6000], x="group_id", y="likes_overall_all", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="4e90d996-3e9c-4460-8f79-1fad1649c9a1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4e90d996-3e9c-4460-8f79-1fad1649c9a1")) {
#                     Plotly.newPlot(
#                         '4e90d996-3e9c-4460-8f79-1fad1649c9a1',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>likes_overall_all=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["aleshafond", "changeonelife", "corvids_nest", "domsg", "donorsearch", "faktu_taina", "fhr", "foma_magazine", "fondbezrukova", "foodbankrus", "khl", "moscowbattery", "olympic_russia", "pauline_school3", "pfcfakel", "poisk_vzroslyh74", "pomogat_legko", "rgymrussia", "teamrussia", "teplypriem", "uralafonofficial", "valaam", "vosprf", "vpravoslav", "wrestrus_ru", "yarspas", "zoolimpopo"], "xaxis": "x", "y": [18961.0, 9179.0, 7671.0, 6872.0, 9086.0, 8847.0, 7461.0, 8330.0, 6896.0, 7664.0, 11876.0, 27253.0, 8676.0, 8078.0, 12416.0, 7135.0, 12282.0, 11585.0, 12407.0, 8869.0, 6806.0, 7937.0, 6285.0, 83005.0, 6342.0, 6388.0, 7245.0], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig = px.bar(ngo_vks[ngo_vks["likes_mean_all"] > 200], x="group_id", y="likes_mean_all", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="2e33d386-2904-47b8-ba0b-017f3f8a5493" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2e33d386-2904-47b8-ba0b-017f3f8a5493")) {
#                     Plotly.newPlot(
#                         '2e33d386-2904-47b8-ba0b-017f3f8a5493',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>likes_mean_all=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["adel.vasilev", "aleshafond", "amfr_official", "aviasalesru", "changeonelife", "children_hospice", "corvids_nest", "cultrf", "domsg", "donorsearch", "dynamo_ru", "faktu_taina", "fhr", "foma_magazine", "fondbezrukova", "foodbankrus", "hclokomotiv_official", "histrfvk", "islamdagru", "khl", "kickboxingfkr", "ladya_zima", "lesnoj_priyut", "monasterygoric", "moscowbattery", "moscowtheologicalacademy", "moypolk", "olympic_russia", "onfront", "paradox_45", "pauline_school3", "pfcfakel", "podaryzhizn", "poisk_vzroslyh74", "pomogat_legko", "rgymrussia", "rosatomru", "rso_official", "russianjudofederation", "sadhguru", "teamrussia", "teplypriem", "uazrussia", "un.armia", "uralafonofficial", "valaam", "vosprf", "vpravoslav", "vsezapobedu", "wrestrus_ru", "yarspas", "zoolimpopo"], "xaxis": "x", "y": [430.0, 948.05, 209.5, 275.25, 458.95, 256.75, 383.55, 227.9, 343.6, 454.3, 257.35, 442.35, 373.05, 416.5, 344.8, 383.2, 294.7, 212.7, 271.7, 593.8, 281.35, 214.6, 249.45, 211.2, 1362.65, 278.2, 290.95, 433.8, 278.6, 274.85, 403.9, 620.8, 256.35, 356.75, 614.1, 579.25, 291.7, 278.35, 232.8, 286.5, 620.35, 443.45, 235.0, 252.8, 340.3, 396.85, 314.25, 4150.25, 214.3, 317.1, 319.4, 362.25], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig = px.bar(ngo_vks[ngo_vks["comments_overall_all"] > 200], x="group_id", y="comments_overall_all", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="0da4b31d-7648-42a8-8f86-5387a2aa8125" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0da4b31d-7648-42a8-8f86-5387a2aa8125")) {
#                     Plotly.newPlot(
#                         '0da4b31d-7648-42a8-8f86-5387a2aa8125',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>comments_overall_all=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["4istaya_vuoksa", "aleshafond", "alexander.kovtunets", "alliance4animals", "aviasalesru", "azovsky", "bakirovo33", "bfp_istokzhizni", "bfpeaceandlove", "bolezn_behtereva", "changeonelife", "corvids_nest", "dislife_ru", "domsg", "donorsearch", "dynamo_ru", "er_ru", "faktu_taina", "fc_textil", "fctambov68", "fculvolga", "fhr", "fondbezrukova", "gkavtodor", "gkh_kontrol_official", "hclokomotiv_official", "histrfvk", "hrushigroup", "ignchurch", "insomniafestru", "instfinru", "invoku", "khl", "kirov_ldpr", "krugdobrafund", "m_s_m_r", "mam33", "max_shugaley", "music_mirmio", "obr_razvitum", "onfront", "otkritiecorp", "paradox_45", "pauline_school3", "pavtur", "pedsovet", "peredvizhnik_ru", "pfcfakel", "poigrai", "profpravda", "radioteos", "rgymrussia", "rosatomru", "rosavtoprestizh", "rostelecom", "rsbor", "rzhev_dobro", "rzn_hunt", "sadhguru", "sevbalru", "sibhl", "spartakhc", "svo196", "takiedela_ru", "tankbiathlon", "teamrussia", "teplypriem", "torok_3d", "tourismsamara", "ttk", "uazrussia", "veleskurgan", "voblagodetym", "vpravoslav", "vtb", "yaprivit", "zoolimpopo"], "xaxis": "x", "y": [206.0, 417.0, 649.0, 540.0, 896.0, 355.0, 324.0, 334.0, 573.0, 497.0, 461.0, 298.0, 218.0, 208.0, 948.0, 361.0, 269.0, 462.0, 288.0, 298.0, 313.0, 236.0, 444.0, 428.0, 208.0, 488.0, 230.0, 226.0, 370.0, 733.0, 407.0, 502.0, 436.0, 240.0, 241.0, 214.0, 218.0, 203.0, 32763.0, 203.0, 372.0, 1173.0, 590.0, 358.0, 308.0, 224.0, 1195.0, 1552.0, 287.0, 647.0, 298.0, 226.0, 268.0, 543.0, 9097.0, 243.0, 832.0, 655.0, 208.0, 319.0, 693.0, 328.0, 321.0, 303.0, 361.0, 497.0, 402.0, 333.0, 319.0, 418.0, 1535.0, 370.0, 640.0, 1518.0, 1153.0, 1441.0, 232.0], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig = px.bar(ngo_vks[ngo_vks["reposts_overall_all"] > 5000], x="group_id", y="reposts_overall_all", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="580d9e29-82bd-4778-996c-fadb1476fc11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("580d9e29-82bd-4778-996c-fadb1476fc11")) {
#                     Plotly.newPlot(
#                         '580d9e29-82bd-4778-996c-fadb1476fc11',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>reposts_overall_all=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["aleshafond", "aviasalesru", "changeonelife", "children_hospice", "corvids_nest", "domsg", "donorsearch", "dynamo_ru", "faktu_taina", "fhr", "foma_magazine", "fondbezrukova", "foodbankrus", "hclokomotiv_official", "islamdagru", "khl", "kickboxingfkr", "moscowbattery", "moscowtheologicalacademy", "moypolk", "olympic_russia", "onfront", "paradox_45", "pauline_school3", "pfcfakel", "podaryzhizn", "poisk_vzroslyh74", "pomogat_legko", "rgymrussia", "rosatomru", "rso_official", "sadhguru", "teamrussia", "teplypriem", "un.armia", "uralafonofficial", "valaam", "vosprf", "vpravoslav", "wrestrus_ru", "yarspas", "zoolimpopo"], "xaxis": "x", "y": [18961.0, 5505.0, 9179.0, 5135.0, 7671.0, 6872.0, 9086.0, 5147.0, 8847.0, 7461.0, 8330.0, 6896.0, 7664.0, 5894.0, 5434.0, 11876.0, 5627.0, 27253.0, 5564.0, 5819.0, 8676.0, 5572.0, 5497.0, 8078.0, 12416.0, 5127.0, 7135.0, 12282.0, 11585.0, 5834.0, 5567.0, 5730.0, 12407.0, 8869.0, 5056.0, 6806.0, 7937.0, 6285.0, 83005.0, 6342.0, 6388.0, 7245.0], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig = px.bar(ngo_vks[ngo_vks["reposts_mean_all"] > 200], x="group_id", y="reposts_mean_all", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="5b1b00f3-b251-4782-b79e-f81ff1eac8a0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5b1b00f3-b251-4782-b79e-f81ff1eac8a0")) {
#                     Plotly.newPlot(
#                         '5b1b00f3-b251-4782-b79e-f81ff1eac8a0',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>reposts_mean_all=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["adel.vasilev", "aleshafond", "amfr_official", "aviasalesru", "changeonelife", "children_hospice", "corvids_nest", "cultrf", "domsg", "donorsearch", "dynamo_ru", "faktu_taina", "fhr", "foma_magazine", "fondbezrukova", "foodbankrus", "hclokomotiv_official", "histrfvk", "islamdagru", "khl", "kickboxingfkr", "ladya_zima", "lesnoj_priyut", "monasterygoric", "moscowbattery", "moscowtheologicalacademy", "moypolk", "olympic_russia", "onfront", "paradox_45", "pauline_school3", "pfcfakel", "podaryzhizn", "poisk_vzroslyh74", "pomogat_legko", "rgymrussia", "rosatomru", "rso_official", "russianjudofederation", "sadhguru", "teamrussia", "teplypriem", "uazrussia", "un.armia", "uralafonofficial", "valaam", "vosprf", "vpravoslav", "vsezapobedu", "wrestrus_ru", "yarspas", "zoolimpopo"], "xaxis": "x", "y": [430.0, 948.05, 209.5, 275.25, 458.95, 256.75, 383.55, 227.9, 343.6, 454.3, 257.35, 442.35, 373.05, 416.5, 344.8, 383.2, 294.7, 212.7, 271.7, 593.8, 281.35, 214.6, 249.45, 211.2, 1362.65, 278.2, 290.95, 433.8, 278.6, 274.85, 403.9, 620.8, 256.35, 356.75, 614.1, 579.25, 291.7, 278.35, 232.8, 286.5, 620.35, 443.45, 235.0, 252.8, 340.3, 396.85, 314.25, 4150.25, 214.3, 317.1, 319.4, 362.25], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig = px.bar(ngo_vks[ngo_vks["views_overall_all"] > 190000], x="group_id", y="views_overall_all", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="cba7b237-5379-4216-ba49-59b78cd24e2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cba7b237-5379-4216-ba49-59b78cd24e2e")) {
#                     Plotly.newPlot(
#                         'cba7b237-5379-4216-ba49-59b78cd24e2e',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>views_overall_all=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["aleshafond", "amfr_official", "angiolsurgery", "applevk", "aviasalesru", "bfdetmir", "changeonelife", "children_hospice", "corvids_nest", "cultrf", "cybathletics", "donorsearch", "extremum", "faktu_taina", "fctambov68", "fhr", "foma_magazine", "fondbezrukova", "foodbankrus", "gorbunok72", "hclokomotiv_official", "insomniafestru", "kesbasket", "khl", "kickboxingfkr", "kinoartmag", "letovoschool", "lokoliga", "lukoil", "mamadomfond", "mc21vek", "medsestre", "moscowtheologicalacademy", "nazaccent", "notariat_ru", "novatek_ru", "nslabs", "obyasnyaemrf", "olympic_russia", "onfront", "otkritiecorp", "pauline_school3", "pedsovet", "pfcfakel", "poisk_vzroslyh74", "potomuchtoludi", "rboo_mig", "rfsruofficial", "rgymrussia", "rosatomru", "rostelecom", "rso_official", "russian.seasons", "sadhguru", "sirius.talents", "svo196", "takiedela_ru", "teamrussia", "teplypriem", "tildapublishing", "timchenko_foundation", "uazrussia", "un.armia", "vizimbir", "voennayaipoteka1", "vosprf", "vpravoslav", "vsezapobedu", "vtb", "vtbkremlincup", "wrestrus_ru", "yarspas", "young_readers", "zoolimpopo"], "xaxis": "x", "y": [268315.0, 612949.0, 231526.0, 200944.0, 599313.0, 224690.0, 354528.0, 293608.0, 212168.0, 267429.0, 318591.0, 444680.0, 218789.0, 1591590.0, 259068.0, 560607.0, 291208.0, 377854.0, 224781.0, 231195.0, 352408.0, 217841.0, 311602.0, 989116.0, 347083.0, 307601.0, 232268.0, 235587.0, 198991.0, 202383.0, 204775.0, 210623.0, 191531.0, 619426.0, 225601.0, 268796.0, 240355.0, 1376060.0, 550223.0, 214088.0, 2486588.0, 956833.0, 255241.0, 475936.0, 454206.0, 5347851.0, 251265.0, 238445.0, 579325.0, 310805.0, 5504347.0, 317181.0, 293460.0, 199655.0, 492926.0, 292761.0, 284027.0, 780245.0, 252222.0, 282802.0, 293776.0, 279608.0, 282679.0, 307564.0, 334753.0, 383361.0, 1327949.0, 570539.0, 7081701.0, 1259657.0, 519815.0, 280723.0, 260341.0, 459325.0], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig = px.bar(ngo_vks[ngo_vks["views_mean_all"] > 20000], x="group_id", y="views_mean_all", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="1c4829ac-dc01-44a9-8a95-2ac3964038d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1c4829ac-dc01-44a9-8a95-2ac3964038d3")) {
#                     Plotly.newPlot(
#                         '1c4829ac-dc01-44a9-8a95-2ac3964038d3',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>views_mean_all=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["amfr_official", "aviasalesru", "donorsearch", "faktu_taina", "fhr", "khl", "nazaccent", "obyasnyaemrf", "olympic_russia", "otkritiecorp", "pauline_school3", "pfcfakel", "poisk_vzroslyh74", "potomuchtoludi", "rgymrussia", "rostelecom", "sirius.talents", "teamrussia", "vpravoslav", "vsezapobedu", "vtb", "vtbkremlincup", "wrestrus_ru", "zoolimpopo"], "xaxis": "x", "y": [30647.45, 29965.65, 22234.0, 79579.5, 28030.35, 49455.8, 30971.3, 68803.0, 27511.15, 124329.4, 47841.65, 23796.8, 22710.3, 267392.55, 28966.25, 275217.35, 24646.3, 39012.25, 66397.45, 28526.95, 354085.05, 62982.85, 25990.75, 22966.25], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...

# %%
fig = px.bar(ngo_vks[ngo_vks["ads_overall_all"] > 0], x="group_id", y="ads_overall_all", title="Stats")
fig.update_layout(barmode='stack', xaxis={'categoryorder':'total descending'})
fig.show()
# Out:
# <div>
#
#
#             <div id="3fd8e64f-383c-4cee-a370-9a18af3f2254" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3fd8e64f-383c-4cee-a370-9a18af3f2254")) {
#                     Plotly.newPlot(
#                         '3fd8e64f-383c-4cee-a370-9a18af3f2254',
#                         [{"alignmentgroup": "True", "hovertemplate": "group_id=%{x}<br>ads_overall_all=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["aif.karelia", "alexander.kovtunets", "applevk", "autoshkola_specialist", "history4you", "karelnok", "ludi_rosta", "malinavto", "mayaksbor", "prochad", "ptzgovorit", "tvbalezino"], "xaxis": "x", "y": [1.0, 1.0, 6.0, 1.0, 1.0, 1.0, 1.0, 2.0, 2.0, 4.0, 1.0, 1.0], "yaxis": "y"}],
#                         {"barmode": "stack", "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar ...
